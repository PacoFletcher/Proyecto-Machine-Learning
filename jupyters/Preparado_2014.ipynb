# %% [markdown]
# # Preparación 2014

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2014_ACCIDENTS_GU_BCN_2014.csv", encoding="Windows 1252")
df2 = pd.read_csv("../data/2014_ACCIDENTS_TIPUS_GU_BCN_2014.csv", encoding="cp850")

# %%
df1
# Out:
#      Número d'expedient  Codi districte Nom districte   NK barri  \
# 0           2014S007072              -1    Desconegut   -1--1--1
# 1           2014S000436              -1    Desconegut   -1--1--1
# 2           2014S003380              10    Sant Martí  101-10-64
# 3           2014S002456              10    Sant Martí  101-10-64
# 4           2014S006504              10    Sant Martí  101-10-64
# ...                 ...             ...           ...        ...
# 9675        2014S006134               9   Sant Andreu    93-9-59
# 9676        2014S009475               9   Sant Andreu    93-9-59
# 9677        2014S006430               9   Sant Andreu    93-9-59
# 9678        2014S008654               9   Sant Andreu    93-9-59
# 9679        2014S002006               9   Sant Andreu    93-9-59
#
#                        Nom barri  Codi carrer                Nom carrer  \
# 0                     Desconegut           -1                Desconegut
# 1                     Desconegut           -1                Desconegut
# 2     el Camp de l'Arpa del Clot       209900                 Meridiana
# 3     el Camp de l'Arpa del Clot       134801                    Freser
# 4     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# ...                          ...          ...                       ...
# 9675               el Bon Pastor       701347              Jaume Brossa
# 9676               el Bon Pastor       701265           Litoral (Besòs)
# 9677               el Bon Pastor       318906                 Santander
# 9678               el Bon Pastor       318906                 Santander
# 9679               el Bon Pastor       318906                 Santander
#
#      Num postal caption Descripció dia setmana  Dia de setmana  ...  \
# 0            Desconegut                 Dijous               4  ...
# 1            Desconegut                Dilluns               1  ...
# 2             0163 0163                 Dijous               4  ...
# 3             0101 0101                 Dijous               4  ...
# 4             0358 0358               Dimecres               3  ...
# ...                 ...                    ...             ...  ...
# 9675          0012 0012                Dilluns               1  ...
# 9676          000180000                Dilluns               1  ...
# 9677          0090 0090               Dissabte               6  ...
# 9678          0120 0122                Dimarts               2  ...
# 9679          0120 0122                Dimarts               2  ...
#
#      Hora de dia  Descripció torn  Descripció causa vianant Número de morts  \
# 0             16            Tarda                Desconegut               0
# 1              9             Matí                Desconegut               0
# 2             13             Matí                Desconegut               0
# 3             10             Matí                Desconegut               0
# 4             14            Tarda                Desconegut               0
# ...          ...              ...                       ...             ...
# 9675           8             Matí                Desconegut               0
# 9676          15            Tarda                Desconegut               0
# 9677          21            Tarda                Desconegut               0
# 9678          12             Matí                Desconegut               0
# 9679          11             Matí                Desconegut               0
#
#       Número de lesionats lleus  Número de lesionats greus Número de víctimes  \
# 0                             1                          0                  1
# 1                             0                          0                  0
# 2                             1                          0                  1
# 3                             1                          0                  1
# 4                             2                          0                  2
# ...                         ...                        ...                ...
# 9675                          1                          0                  1
# 9676                          3                          0                  3
# 9677                          1                          0                  1
# 9678                          2                          0                  2
# 9679                          1                          0                  1
#
#      Número de vehicles implicats  Coordenada UTM (Y)  Coordenada UTM (X)
# 0                               1                  -1                  -1
# 1                               1                  -1                  -1
# 2                               2          4585072,01           432111,21
# 3                               1          4585510,29           431800,00
# 4                               2          4585511,58           431690,10
# ...                           ...                 ...                 ...
# 9675                            2          4587049,98           433194,20
# 9676                            4          4587900,48           433996,60
# 9677                            2          4587203,56           433742,54
# 9678                            2          4587466,65           433913,43
# 9679                            2          4587466,65           433913,43
#
# [9680 rows x 25 columns]

# %%
df1.columns
# Out:
# Index(['Número d'expedient', 'Codi districte', 'Nom districte', 'NK barri',
#        'Nom barri', 'Codi carrer', 'Nom carrer', 'Num postal caption',
#        'Descripció dia setmana', 'Dia de setmana', 'Descripció tipus dia',
#        'NK Any', 'Mes de any', 'Nom mes', 'Dia de mes', 'Hora de dia',
#        'Descripció torn', 'Descripció causa vianant', 'Número de morts',
#        'Número de lesionats lleus', 'Número de lesionats greus',
#        'Número de víctimes', 'Número de vehicles implicats',
#        'Coordenada UTM (Y)', 'Coordenada UTM (X)'],
#       dtype='object')

# %%
df1 = df1.rename(columns={
    "Número d'expedient": "Numero_expedient",
    "Codi districte": "Codi_districte",
    "Nom districte": "Nom_districte",
    "NK barri": "Codi_barri",
    "Nom barri": "Nom_barri",
    "Codi carrer": "Codi_carrer",
    "Nom carrer": "Nom_carrer",
    "Num postal caption": "Num_postal ",
    "Descripció dia setmana": "Descripcio_dia_setmana",
    "NK Any": "NK_Any",
    "Mes de any": "Mes_any",
    "Nom mes": "Nom_mes",
    "Dia de mes": "Dia_mes",
    "Hora de dia": "Hora_dia",
    "Descripció torn": "Descripcio_torn",
    "Descripció causa vianant": "Descripcio_causa_vianant",
    "Número de morts": "Numero_morts",
    "Número de lesionats lleus": "Numero_lesionats_lleus",
    "Número de lesionats greus": "Numero_lesionats_greus",
    "Número de víctimes": "Numero_victimes",
    "Número de vehicles implicats": "Numero_vehicles_implicats",
    "Coordenada UTM (Y)": "Coordenada_UTM_Y_ED50",
    "Coordenada UTM (X)": "Coordenada_UTM_X_ED50"
})

# %%
df2
# Out:
#       Número d'expedient Codi districte Nom districte Codi barri  \
# 0            2014S007794             10    Sant Martí         64
# 1            2014S001086             10    Sant Martí         64
# 2            2014S008488             10    Sant Martí         64
# 3            2014S000086             10    Sant Martí         64
# 4            2014S003039             10    Sant Martí         64
# ...                  ...            ...           ...        ...
# 10152        2014S004510              9   Sant Andreu         59
# 10153        2014S008875              9   Sant Andreu         59
# 10154        2014S005887              9   Sant Andreu         59
# 10155        2014S006311              9   Sant Andreu         59
# 10156        2014S007729              9   Sant Andreu         58
#
#                         Nom barri Codi carrer         Nom carrer  \
# 0      el Camp de l'Arpa del Clot      283200           Ripollès
# 1      el Camp de l'Arpa del Clot      209900          Meridiana
# 2      el Camp de l'Arpa del Clot      209900          Meridiana
# 3      el Camp de l'Arpa del Clot      194406           Maragall
# 4      el Camp de l'Arpa del Clot      194406           Maragall
# ...                           ...         ...                ...
# 10152               el Bon Pastor      701265    Litoral (Besòs)
# 10153               el Bon Pastor      151957          Guayaquil
# 10154               el Bon Pastor      179504               Lima
# 10155               el Bon Pastor       80101  Ciutat d'Asunción
# 10156               Baró de Viver      347551            Tucumán
#
#       Num postal caption Descripció dia setmana Dia setmana  \
# 0              0098 0098               Diumenge          Dg
# 1              0163 0163               Dimecres          Dc
# 2              0181 0181               Dimecres          Dc
# 3              0026 0026               Diumenge          Dg
# 4              0005 0005              Divendres          Dv
# ...                  ...                    ...         ...
# 10152             140000               Dimecres          Dc
# 10153          0009 0009                Dimarts          Dm
# 10154          0005 0005                Dilluns          Dl
# 10155          0016 0016                Dimarts          Dm
# 10156          0021 0025              Divendres          Dv
#
#       Descripció tipus dia  NK Any  Mes de any   Nom mes  Dia de mes  \
# 0                  Laboral    2014          10   Octubre          26
# 1                  Laboral    2014           2    Febrer          12
# 2                  Laboral    2014          11  Novembre          19
# 3                  Laboral    2014           1     Gener           5
# 4                  Laboral    2014           4     Abril          25
# ...                    ...     ...         ...       ...         ...
# 10152              Laboral    2014           6      Juny          18
# 10153              Laboral    2014          12  Desembre           2
# 10154              Laboral    2014           8     Agost          11
# 10155              Laboral    2014           9  Setembre           2
# 10156              Laboral    2014          10   Octubre          24
#
#        Hora de dia Descripció torn   Descripció tipus accident  \
# 0               23             Nit  Xoc contra element estàtic
# 1               11            Matí                       Abast
# 2               11            Matí               Atropellament
# 3               21           Tarda                       Abast
# 4               15           Tarda                       Abast
# ...            ...             ...                         ...
# 10152           18           Tarda           Col.lisió lateral
# 10153           19           Tarda                       Abast
# 10154           18           Tarda    Col.lisió fronto-lateral
# 10155            8            Matí  Xoc contra element estàtic
# 10156           13            Matí               Atropellament
#
#       Coordenada UTM (Y) Coordenada UTM (X)
# 0             4585403,65          432091,32
# 1             4585072,01          432111,21
# 2             4585145,54          432111,72
# 3             4585369,85          431638,05
# 4             4585194,82           431644,1
# ...                  ...                ...
# 10152         4588287,89          433892,17
# 10153         4588218,15          433877,14
# 10154         4588057,84           433406,4
# 10155         4587875,92          433328,51
# 10156         4588851,98          433458,13
#
# [10157 rows x 20 columns]

# %%
df2.columns
# Out:
# Index(['Número d'expedient', 'Codi districte', 'Nom districte', 'Codi barri',
#        'Nom barri', 'Codi carrer', 'Nom carrer', 'Num postal caption',
#        'Descripció dia setmana', 'Dia setmana', 'Descripció tipus dia',
#        'NK Any', 'Mes de any', 'Nom mes', 'Dia de mes', 'Hora de dia',
#        'Descripció torn', 'Descripció tipus accident', 'Coordenada UTM (Y)',
#        'Coordenada UTM (X)'],
#       dtype='object')

# %%
df2 = df2.rename(columns={
    "Número d'expedient": "Numero_expedient",
    "Codi districte": "Codi_districte",
    "Nom districte": "Nom_districte",
    "Codi barri": "Codi_barri",
    "Nom barri": "Nom_barri",
    "Codi carrer": "Codi_carrer",
    "Nom carrer": "Nom_carrer",
    "Num postal caption": "Num_postal ",
    "Descripció dia setmana": "Descripcio_dia_setmana",
    'Dia setmana':"Dia_setmana",
    "NK Any":"NK_Any",
    "Mes de any": "Mes_any",
    "Nom mes": "Nom_mes",
    "Dia de mes": "Dia_mes",
    "Hora de dia": "Hora_dia",
    "Descripció torn": "Descripcio_torn",
    "Descripció tipus accident": "Descripcio_tipus_accident",
    "Coordenada UTM (Y)": "Coordenada_UTM_Y_ED50",
    "Coordenada UTM (X)": "Coordenada_UTM_X_ED50"
})

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on="Numero_expedient")

# %%
df
# Out:
#       Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0          2014S007072              -1    Desconegut   -1--1--1
# 1          2014S003380              10    Sant Martí  101-10-64
# 2          2014S002456              10    Sant Martí  101-10-64
# 3          2014S006504              10    Sant Martí  101-10-64
# 4          2014S003469              10    Sant Martí  101-10-64
# ...                ...             ...           ...        ...
# 10152      2014S006134               9   Sant Andreu    93-9-59
# 10153      2014S009475               9   Sant Andreu    93-9-59
# 10154      2014S006430               9   Sant Andreu    93-9-59
# 10155      2014S008654               9   Sant Andreu    93-9-59
# 10156      2014S002006               9   Sant Andreu    93-9-59
#
#                         Nom_barri  Codi_carrer                Nom_carrer  \
# 0                      Desconegut           -1                Desconegut
# 1      el Camp de l'Arpa del Clot       209900                 Meridiana
# 2      el Camp de l'Arpa del Clot       134801                    Freser
# 3      el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4      el Camp de l'Arpa del Clot        90502                   Còrsega
# ...                           ...          ...                       ...
# 10152               el Bon Pastor       701347              Jaume Brossa
# 10153               el Bon Pastor       701265           Litoral (Besòs)
# 10154               el Bon Pastor       318906                 Santander
# 10155               el Bon Pastor       318906                 Santander
# 10156               el Bon Pastor       318906                 Santander
#
#       Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 0      Desconegut                 Dijous               4  ...           Tarda
# 1       0163 0163                 Dijous               4  ...            Matí
# 2       0101 0101                 Dijous               4  ...            Matí
# 3       0358 0358               Dimecres               3  ...           Tarda
# 4       0711 0711                Dilluns               1  ...            Matí
# ...           ...                    ...             ...  ...             ...
# 10152   0012 0012                Dilluns               1  ...            Matí
# 10153   000180000                Dilluns               1  ...           Tarda
# 10154   0090 0090               Dissabte               6  ...           Tarda
# 10155   0120 0122                Dimarts               2  ...            Matí
# 10156   0120 0122                Dimarts               2  ...            Matí
#
#        Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 0                    Desconegut             0                      1
# 1                    Desconegut             0                      1
# 2                    Desconegut             0                      1
# 3                    Desconegut             0                      2
# 4                    Desconegut             0                      1
# ...                         ...           ...                    ...
# 10152                Desconegut             0                      1
# 10153                Desconegut             0                      3
# 10154                Desconegut             0                      1
# 10155                Desconegut             0                      2
# 10156                Desconegut             0                      1
#
#        Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 0                           0                1                         1
# 1                           0                1                         2
# 2                           0                1                         1
# 3                           0                2                         2
# 4                           0                1                         2
# ...                       ...              ...                       ...
# 10152                       0                1                         2
# 10153                       0                3                         4
# 10154                       0                1                         2
# 10155                       0                2                         2
# 10156                       0                1                         2
#
#       Coordenada_UTM_Y_ED50  Coordenada_UTM_X_ED50  Descripcio_tipus_accident
# 0                        -1                     -1       Caiguda (dues rodes)
# 1                4585072,01              432111,21                      Abast
# 2                4585510,29              431800,00              Atropellament
# 3                4585511,58              431690,10                      Abast
# 4                4585164,06              431643,32          Col.lisió lateral
# ...                     ...                    ...                        ...
# 10152            4587049,98              433194,20   Col.lisió fronto-lateral
# 10153            4587900,48              433996,60             Abast multiple
# 10154            4587203,56              433742,54                      Abast
# 10155            4587466,65              433913,43                      Abast
# 10156            4587466,65              433913,43       Caiguda (dues rodes)
#
# [10157 rows x 26 columns]

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 6544      2014S000006               1  Ciutat Vella     11-1-1
# 6543      2014S000006               1  Ciutat Vella     11-1-1
# 2434      2014S000007               8    Nou Barris    81-8-55
# 2433      2014S000007               8    Nou Barris    81-8-55
# 92        2014S000033              10    Sant Martí  104-10-68
# ...               ...             ...           ...        ...
# 8433      2014S009641               4     Les Corts    41-4-19
# 469       2014S009656               2      Eixample     24-2-7
# 468       2014S009656               2      Eixample     24-2-7
# 559       2014S009680               2      Eixample     24-2-7
# 558       2014S009680               2      Eixample     24-2-7
#
#                    Nom_barri  Codi_carrer        Nom_carrer Num_postal   \
# 6544                el Raval       298605       Santcliment   0023 0023
# 6543                el Raval       298605       Santcliment   0023 0023
# 2434        Ciutat Meridiana       275600  Rasos de Peguera   0002 0002
# 2433        Ciutat Meridiana       275600  Rasos de Peguera   0002 0002
# 92               el Poblenou       186703             Llull   0134 0134
# ...                      ...          ...               ...         ...
# 8433               les Corts       144601          Diagonal   0658 0660
# 469   la Dreta de l'Eixample       169409   Corts Catalanes   0604 0604
# 468   la Dreta de l'Eixample       169409   Corts Catalanes   0604 0604
# 559   la Dreta de l'Eixample       350308          València   0243 0245
# 558   la Dreta de l'Eixample       350308          València   0243 0245
#
#      Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 6544               Dimecres               3  ...             Nit
# 6543               Dimecres               3  ...             Nit
# 2434              Divendres               5  ...            Matí
# 2433              Divendres               5  ...            Matí
# 92                   Dijous               4  ...           Tarda
# ...                     ...             ...  ...             ...
# 8433                Dimarts               2  ...            Matí
# 469                 Dimarts               2  ...           Tarda
# 468                 Dimarts               2  ...           Tarda
# 559                Dimecres               3  ...           Tarda
# 558                Dimecres               3  ...           Tarda
#
#       Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 6544                Desconegut             0                      1
# 6543                Desconegut             0                      1
# 2434                Desconegut             0                      1
# 2433                Desconegut             0                      1
# 92                  Desconegut             0                      1
# ...                        ...           ...                    ...
# 8433                Desconegut             0                      0
# 469                 Desconegut             0                      1
# 468                 Desconegut             0                      1
# 559                 Desconegut             0                      1
# 558                 Desconegut             0                      1
#
#       Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 6544                       0                1                         2
# 6543                       0                1                         2
# 2434                       0                1                         2
# 2433                       0                1                         2
# 92                         0                1                         3
# ...                      ...              ...                       ...
# 8433                       0                0                         7
# 469                        0                1                         2
# 468                        0                1                         2
# 559                        0                1                         4
# 558                        0                1                         4
#
#      Coordenada_UTM_Y_ED50  Coordenada_UTM_X_ED50   Descripcio_tipus_accident
# 6544            4581314,95              430313,99  Xoc contra element estàtic
# 6543            4581314,95              430313,99           Col.lisió lateral
# 2434            4590582,98              431546,71    Col.lisió fronto-lateral
# 2433            4590582,98              431546,71  Xoc contra element estàtic
# 92              4583446,20              433074,50  Xoc contra element estàtic
# ...                    ...                    ...                         ...
# 8433            4582569,67              427346,74           Col.lisió lateral
# 469             4582245,25              430308,02    Col.lisió fronto-lateral
# 468             4582245,25              430308,02                      Altres
# 559             4582858,88              430095,63  Xoc contra element estàtic
# 558             4582858,88              430095,63           Col.lisió lateral
#
# [955 rows x 26 columns]

# %%
df = df.rename(columns={
    'Coordenada_UTM_X_ED50':"Coordenada_UTM_X",
       'Coordenada_UTM_Y_ED50':"Coordenada_UTM_Y",
         'Longitud_WGS84':"Longitud",
           'Latitud_WGS84':"Latitud"
})
df
# Out:
#       Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0          2014S007072              -1    Desconegut   -1--1--1
# 1          2014S003380              10    Sant Martí  101-10-64
# 2          2014S002456              10    Sant Martí  101-10-64
# 3          2014S006504              10    Sant Martí  101-10-64
# 4          2014S003469              10    Sant Martí  101-10-64
# ...                ...             ...           ...        ...
# 10152      2014S006134               9   Sant Andreu    93-9-59
# 10153      2014S009475               9   Sant Andreu    93-9-59
# 10154      2014S006430               9   Sant Andreu    93-9-59
# 10155      2014S008654               9   Sant Andreu    93-9-59
# 10156      2014S002006               9   Sant Andreu    93-9-59
#
#                         Nom_barri  Codi_carrer                Nom_carrer  \
# 0                      Desconegut           -1                Desconegut
# 1      el Camp de l'Arpa del Clot       209900                 Meridiana
# 2      el Camp de l'Arpa del Clot       134801                    Freser
# 3      el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4      el Camp de l'Arpa del Clot        90502                   Còrsega
# ...                           ...          ...                       ...
# 10152               el Bon Pastor       701347              Jaume Brossa
# 10153               el Bon Pastor       701265           Litoral (Besòs)
# 10154               el Bon Pastor       318906                 Santander
# 10155               el Bon Pastor       318906                 Santander
# 10156               el Bon Pastor       318906                 Santander
#
#       Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 0      Desconegut                 Dijous               4  ...           Tarda
# 1       0163 0163                 Dijous               4  ...            Matí
# 2       0101 0101                 Dijous               4  ...            Matí
# 3       0358 0358               Dimecres               3  ...           Tarda
# 4       0711 0711                Dilluns               1  ...            Matí
# ...           ...                    ...             ...  ...             ...
# 10152   0012 0012                Dilluns               1  ...            Matí
# 10153   000180000                Dilluns               1  ...           Tarda
# 10154   0090 0090               Dissabte               6  ...           Tarda
# 10155   0120 0122                Dimarts               2  ...            Matí
# 10156   0120 0122                Dimarts               2  ...            Matí
#
#        Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 0                    Desconegut             0                      1
# 1                    Desconegut             0                      1
# 2                    Desconegut             0                      1
# 3                    Desconegut             0                      2
# 4                    Desconegut             0                      1
# ...                         ...           ...                    ...
# 10152                Desconegut             0                      1
# 10153                Desconegut             0                      3
# 10154                Desconegut             0                      1
# 10155                Desconegut             0                      2
# 10156                Desconegut             0                      1
#
#        Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 0                           0                1                         1
# 1                           0                1                         2
# 2                           0                1                         1
# 3                           0                2                         2
# 4                           0                1                         2
# ...                       ...              ...                       ...
# 10152                       0                1                         2
# 10153                       0                3                         4
# 10154                       0                1                         2
# 10155                       0                2                         2
# 10156                       0                1                         2
#
#       Coordenada_UTM_Y  Coordenada_UTM_X  Descripcio_tipus_accident
# 0                   -1                -1       Caiguda (dues rodes)
# 1           4585072,01         432111,21                      Abast
# 2           4585510,29         431800,00              Atropellament
# 3           4585511,58         431690,10                      Abast
# 4           4585164,06         431643,32          Col.lisió lateral
# ...                ...               ...                        ...
# 10152       4587049,98         433194,20   Col.lisió fronto-lateral
# 10153       4587900,48         433996,60             Abast multiple
# 10154       4587203,56         433742,54                      Abast
# 10155       4587466,65         433913,43                      Abast
# 10156       4587466,65         433913,43       Caiguda (dues rodes)
#
# [10157 rows x 26 columns]

# %%
df["Codi_barri"] = df["Codi_barri"].astype(str).str.extract(r'-?(\d+)$')
df
# Out:
#       Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0          2014S007072              -1    Desconegut          1
# 1          2014S003380              10    Sant Martí         64
# 2          2014S002456              10    Sant Martí         64
# 3          2014S006504              10    Sant Martí         64
# 4          2014S003469              10    Sant Martí         64
# ...                ...             ...           ...        ...
# 10152      2014S006134               9   Sant Andreu         59
# 10153      2014S009475               9   Sant Andreu         59
# 10154      2014S006430               9   Sant Andreu         59
# 10155      2014S008654               9   Sant Andreu         59
# 10156      2014S002006               9   Sant Andreu         59
#
#                         Nom_barri  Codi_carrer                Nom_carrer  \
# 0                      Desconegut           -1                Desconegut
# 1      el Camp de l'Arpa del Clot       209900                 Meridiana
# 2      el Camp de l'Arpa del Clot       134801                    Freser
# 3      el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4      el Camp de l'Arpa del Clot        90502                   Còrsega
# ...                           ...          ...                       ...
# 10152               el Bon Pastor       701347              Jaume Brossa
# 10153               el Bon Pastor       701265           Litoral (Besòs)
# 10154               el Bon Pastor       318906                 Santander
# 10155               el Bon Pastor       318906                 Santander
# 10156               el Bon Pastor       318906                 Santander
#
#       Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 0      Desconegut                 Dijous               4  ...           Tarda
# 1       0163 0163                 Dijous               4  ...            Matí
# 2       0101 0101                 Dijous               4  ...            Matí
# 3       0358 0358               Dimecres               3  ...           Tarda
# 4       0711 0711                Dilluns               1  ...            Matí
# ...           ...                    ...             ...  ...             ...
# 10152   0012 0012                Dilluns               1  ...            Matí
# 10153   000180000                Dilluns               1  ...           Tarda
# 10154   0090 0090               Dissabte               6  ...           Tarda
# 10155   0120 0122                Dimarts               2  ...            Matí
# 10156   0120 0122                Dimarts               2  ...            Matí
#
#        Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 0                    Desconegut             0                      1
# 1                    Desconegut             0                      1
# 2                    Desconegut             0                      1
# 3                    Desconegut             0                      2
# 4                    Desconegut             0                      1
# ...                         ...           ...                    ...
# 10152                Desconegut             0                      1
# 10153                Desconegut             0                      3
# 10154                Desconegut             0                      1
# 10155                Desconegut             0                      2
# 10156                Desconegut             0                      1
#
#        Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 0                           0                1                         1
# 1                           0                1                         2
# 2                           0                1                         1
# 3                           0                2                         2
# 4                           0                1                         2
# ...                       ...              ...                       ...
# 10152                       0                1                         2
# 10153                       0                3                         4
# 10154                       0                1                         2
# 10155                       0                2                         2
# 10156                       0                1                         2
#
#       Coordenada_UTM_Y  Coordenada_UTM_X  Descripcio_tipus_accident
# 0                   -1                -1       Caiguda (dues rodes)
# 1           4585072,01         432111,21                      Abast
# 2           4585510,29         431800,00              Atropellament
# 3           4585511,58         431690,10                      Abast
# 4           4585164,06         431643,32          Col.lisió lateral
# ...                ...               ...                        ...
# 10152       4587049,98         433194,20   Col.lisió fronto-lateral
# 10153       4587900,48         433996,60             Abast multiple
# 10154       4587203,56         433742,54                      Abast
# 10155       4587466,65         433913,43                      Abast
# 10156       4587466,65         433913,43       Caiguda (dues rodes)
#
# [10157 rows x 26 columns]

# %%
df["Longitud"] = None
df["Latitud"]= None

# %%
df
# Out:
#       Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0          2014S007072              -1    Desconegut          1
# 1          2014S003380              10    Sant Martí         64
# 2          2014S002456              10    Sant Martí         64
# 3          2014S006504              10    Sant Martí         64
# 4          2014S003469              10    Sant Martí         64
# ...                ...             ...           ...        ...
# 10152      2014S006134               9   Sant Andreu         59
# 10153      2014S009475               9   Sant Andreu         59
# 10154      2014S006430               9   Sant Andreu         59
# 10155      2014S008654               9   Sant Andreu         59
# 10156      2014S002006               9   Sant Andreu         59
#
#                         Nom_barri  Codi_carrer                Nom_carrer  \
# 0                      Desconegut           -1                Desconegut
# 1      el Camp de l'Arpa del Clot       209900                 Meridiana
# 2      el Camp de l'Arpa del Clot       134801                    Freser
# 3      el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4      el Camp de l'Arpa del Clot        90502                   Còrsega
# ...                           ...          ...                       ...
# 10152               el Bon Pastor       701347              Jaume Brossa
# 10153               el Bon Pastor       701265           Litoral (Besòs)
# 10154               el Bon Pastor       318906                 Santander
# 10155               el Bon Pastor       318906                 Santander
# 10156               el Bon Pastor       318906                 Santander
#
#       Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Numero_morts  \
# 0      Desconegut                 Dijous               4  ...            0
# 1       0163 0163                 Dijous               4  ...            0
# 2       0101 0101                 Dijous               4  ...            0
# 3       0358 0358               Dimecres               3  ...            0
# 4       0711 0711                Dilluns               1  ...            0
# ...           ...                    ...             ...  ...          ...
# 10152   0012 0012                Dilluns               1  ...            0
# 10153   000180000                Dilluns               1  ...            0
# 10154   0090 0090               Dissabte               6  ...            0
# 10155   0120 0122                Dimarts               2  ...            0
# 10156   0120 0122                Dimarts               2  ...            0
#
#        Numero_lesionats_lleus  Numero_lesionats_greus Numero_victimes  \
# 0                           1                       0               1
# 1                           1                       0               1
# 2                           1                       0               1
# 3                           2                       0               2
# 4                           1                       0               1
# ...                       ...                     ...             ...
# 10152                       1                       0               1
# 10153                       3                       0               3
# 10154                       1                       0               1
# 10155                       2                       0               2
# 10156                       1                       0               1
#
#        Numero_vehicles_implicats  Coordenada_UTM_Y Coordenada_UTM_X  \
# 0                              1                -1               -1
# 1                              2        4585072,01        432111,21
# 2                              1        4585510,29        431800,00
# 3                              2        4585511,58        431690,10
# 4                              2        4585164,06        431643,32
# ...                          ...               ...              ...
# 10152                          2        4587049,98        433194,20
# 10153                          4        4587900,48        433996,60
# 10154                          2        4587203,56        433742,54
# 10155                          2        4587466,65        433913,43
# 10156                          2        4587466,65        433913,43
#
#       Descripcio_tipus_accident  Longitud  Latitud
# 0          Caiguda (dues rodes)      None     None
# 1                         Abast      None     None
# 2                 Atropellament      None     None
# 3                         Abast      None     None
# 4             Col.lisió lateral      None     None
# ...                         ...       ...      ...
# 10152  Col.lisió fronto-lateral      None     None
# 10153            Abast multiple      None     None
# 10154                     Abast      None     None
# 10155                     Abast      None     None
# 10156      Caiguda (dues rodes)      None     None
#
# [10157 rows x 28 columns]

# %%
df.to_csv("../data/df_2014.csv", index = False)

# %%
#df.groupby("Numero_expedient").sum("")
