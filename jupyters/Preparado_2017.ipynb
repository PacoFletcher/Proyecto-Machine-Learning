# %% [markdown]
# # Preparación 2017

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2018_accidents_gu_bcn.csv")
df2 = pd.read_csv("../data/2018_accidents_tipus_gu_bcn_.csv")

# %%
df1
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0     2018S000150                   3  Sants-Montjuïc          12
# 1     2018S000761                   3  Sants-Montjuïc          11
# 2     2018S005151                   3  Sants-Montjuïc          12
# 3     2018S000933                   3  Sants-Montjuïc          12
# 4     2018S006926                   3  Sants-Montjuïc          12
# ...               ...             ...             ...         ...
# 9931  2018S003036                   8      Nou Barris          55
# 9932  2018S003108                   8      Nou Barris          55
# 9933  2018S009777                   8      Nou Barris          55
# 9934  2018S000005                   8      Nou Barris          56
# 9935  2018S004375                   8      Nou Barris          56
#
#                        Nom_barri  Codi_carrer  \
# 0     la Marina del Prat Vermell       701819
# 1                   el Poble-sec       234001
# ...

# %%
df2
# Out:
#         Codi_expedient  Codi_districte        Nom_districte  Codi_barri  \
# 0      2018S000001                   3       Sants-Montjuïc          11
# 1      2018S000002                   2             Eixample           9
# 2      2018S000003                  10           Sant Martí          64
# 3      2018S000004                   8           Nou Barris          44
# 4      2018S000005                   8           Nou Barris          56
# ...                ...             ...                  ...         ...
# 10546  2018S009968                   4            Les Corts          20
# 10547  2018S009969                   3       Sants-Montjuïc          14
# 10548  2018S009971                   7       Horta-Guinardó          34
# 10549  2018S009972                   9          Sant Andreu          63
# 10550  2018S009973                   5  Sarrià-Sant Gervasi          26
#
#                             Nom_barri  Codi_carrer  \
# ...

# %%
df = df1.merge(df2[["Codi_expedient","Tipus_accident"]], how = "inner", left_on="Numero_expedient" ,right_on= "Codi_expedient")

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 7920  2018S000023                   6        Gràcia          30
# 7921  2018S000023                   6        Gràcia          30
# 9263  2018S000041                  10    Sant Martí          73
# 9262  2018S000041                  10    Sant Martí          73
# 709   2018S000051                   1  Ciutat Vella           1
# ...               ...             ...           ...         ...
# 4556  2018S009929                   2      Eixample           8
# 2805  2018S009962                   4     Les Corts          20
# 2804  2018S009962                   4     Les Corts          20
# 8853  2018S009966                   9   Sant Andreu          61
# 8854  2018S009966                   9   Sant Andreu          61
#
#                             Nom_barri  Codi_carrer  \
# 7920                         la Salut       344000
# 7921                         la Salut       344000
# ...

# %%
df.rename(columns={"Tipus_accident":"Descripcio_tipus_accident"},inplace=True)

# %%
dum = pd.get_dummies(df["Descripcio_tipus_accident"]).astype("uint8")

# %%
df = pd.concat([df.drop(columns="Descripcio_tipus_accident"),dum],axis = 1)
df
# Out:
#       Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0      2018S000150                   3  Sants-Montjuïc          12
# 1      2018S000150                   3  Sants-Montjuïc          12
# 2      2018S000761                   3  Sants-Montjuïc          11
# 3      2018S000761                   3  Sants-Montjuïc          11
# 4      2018S005151                   3  Sants-Montjuïc          12
# ...                ...             ...             ...         ...
# 10557  2018S003036                   8      Nou Barris          55
# 10558  2018S003108                   8      Nou Barris          55
# 10559  2018S009777                   8      Nou Barris          55
# 10560  2018S000005                   8      Nou Barris          56
# 10561  2018S004375                   8      Nou Barris          56
#
#                         Nom_barri  Codi_carrer  \
# 0      la Marina del Prat Vermell       701819
# 1      la Marina del Prat Vermell       701819
# ...

# %%
#df.groupby("Numero_expedient").sum("")
