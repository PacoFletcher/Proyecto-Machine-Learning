# %% [markdown]
# # Preparación 2017

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2017_accidents_gu_bcn.csv")
df2 = pd.read_csv("../data/2017_accidents_tipus_gu_bcn_.csv")

# %%
df1
# Out:
#       Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0      2017S008429                  -1    Desconegut          -1
# 1      2017S007316                  -1    Desconegut          -1
# 2      2017S010210                  -1    Desconegut          -1
# 3      2017S006364                  -1    Desconegut          -1
# 4      2017S004615                  10    Sant Martí          64
# ...                ...             ...           ...         ...
# 10334  2017S003667                   9   Sant Andreu          59
# 10335  2017S001896                   9   Sant Andreu          59
# 10336  2017S010718                   9   Sant Andreu          59
# 10337  2017S006145                   9   Sant Andreu          59
# 10338  2017S000178                   9   Sant Andreu          59
#
#                         Nom_barri  Codi_carrer  \
# 0                      Desconegut           -1
# 1                      Desconegut           -1
# ...

# %%
df2
# Out:
#       Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0      2017S009418                  -1    Desconegut          -1
# 1      2017S008852                  -1    Desconegut          -1
# 2      2017S001023                  10    Sant Martí          64
# 3      2017S009198                  10    Sant Martí          64
# 4      2017S006546                  10    Sant Martí          64
# ...                ...             ...           ...         ...
# 11004  2017S003667                   9   Sant Andreu          59
# 11005  2017S002192                   9   Sant Andreu          59
# 11006  2017S001766                   9   Sant Andreu          59
# 11007  2017S009106                   9   Sant Andreu          59
# 11008  2017S006503                   9   Sant Andreu          59
#
#                         Nom_barri  Codi_carrer  \
# 0                      Desconegut           -1
# 1                      Desconegut           -1
# ...

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on="Numero_expedient")

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 9789  2017S000005                  10      Sant Martí          66
# 9788  2017S000005                  10      Sant Martí          66
# 8989  2017S000026                   3  Sants-Montjuïc          18
# 8991  2017S000026                   3  Sants-Montjuïc          18
# 8990  2017S000026                   3  Sants-Montjuïc          18
# ...               ...             ...             ...         ...
# 4503  2017S010721                   2        Eixample           7
# 2078  2017S010745                   3  Sants-Montjuïc          18
# 2079  2017S010745                   3  Sants-Montjuïc          18
# 6931  2017S010782                  10      Sant Martí          66
# 6932  2017S010782                  10      Sant Martí          66
#
#                               Nom_barri  Codi_carrer  \
# 9789  el Parc i la Llacuna del Poblenou       243206
# 9788  el Parc i la Llacuna del Poblenou       243206
# ...

# %%
df.to_csv("../data/df_2017.csv", index = False)

# %%
#df.groupby("Numero_expedient").sum("")
