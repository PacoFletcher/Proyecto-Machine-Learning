# %% [markdown]
# # Preparación 2023

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("../data/2023_accidents_gu_bcn.csv")
df2 = pd.read_csv("../data/2023_accidents_tipus_gu_bcn.csv")

# %%
df1
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0     2023S000001                   3  Sants-Montjuïc          18
# 1     2023S000002                   7  Horta-Guinardó          33
# 2     2023S000003                   1    Ciutat Vella           1
# 3     2023S000005                   6          Gràcia          31
# 4     2023S000006                   6          Gràcia          31
# ...               ...             ...             ...         ...
# 7719  2023S007738                  10      Sant Martí          69
# 7720  2023S007739                   6          Gràcia          32
# 7721  2023S007740                   4       Les Corts          20
# 7722  2023S007741                   4       Les Corts          20
# 7723  2023S007742                   4       Les Corts          20
#
#                                          Nom_barri  Codi_carrer  \
# 0                                            Sants        30602
# ...

# %%
df2
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri   Nom_barri  \
# 0     2023S004127                  -1    Desconegut          -1  Desconegut
# 1     2023S003871                  -1    Desconegut          -1  Desconegut
# 2     2023S005242                  -1    Desconegut          -1  Desconegut
# 3     2023S005352                  -1    Desconegut          -1  Desconegut
# 4     2023S007652                  -1    Desconegut          -1  Desconegut
# ...               ...             ...           ...         ...         ...
# 7818  2023S003234                   8    Nou Barris          45       Porta
# 7819  2023S001730                   8    Nou Barris          45       Porta
# 7820  2023S007502                   8    Nou Barris          45       Porta
# 7821  2023S006017                   8    Nou Barris          45       Porta
# 7822  2023S007283                   8    Nou Barris          45       Porta
#
# ...

# %%
df1["Numero_expedient"].sort_values()
# Out:
# 0       2023S000001
# 1       2023S000002
# 2       2023S000003
# 3       2023S000005
# 4       2023S000006
#              ...
# 7719    2023S007738
# 7720    2023S007739
# 7721    2023S007740
# 7722    2023S007741
# 7723    2023S007742
# Name: Numero_expedient, Length: 7724, dtype: object

# %%
df2["Numero_expedient"].sort_values()
# Out:
# 2411    2023S000001
# 5669    2023S000002
# 1069    2023S000003
# 2631    2023S000005
# 3649    2023S000006
#              ...
# 5945    2023S007738
# 4606    2023S007739
# 7395    2023S007740
# 3507    2023S007741
# 6443    2023S007742
# Name: Numero_expedient, Length: 7823, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7724 entries, 0 to 7723
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           7724 non-null   object
#  1   Codi_districte             7724 non-null   int64
#  2   Nom_districte              7724 non-null   object
#  3   Codi_barri                 7724 non-null   int64
#  4   Nom_barri                  7724 non-null   object
#  5   Codi_carrer                7724 non-null   int64
#  6   Nom_carrer                 7724 non-null   object
#  7   Num_postal                 7720 non-null   object
#  8   Descripcio_dia_setmana     7724 non-null   object
#  9   NK_Any                     7724 non-null   int64
#  10  Mes_any                    7724 non-null   int64
#  11  Nom_mes                    7724 non-null   object
#  12  Dia_mes                    7724 non-null   int64
# ...

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on = "Numero_expedient")
df
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0     2023S000001                   3  Sants-Montjuïc          18
# 1     2023S000002                   7  Horta-Guinardó          33
# 2     2023S000003                   1    Ciutat Vella           1
# 3     2023S000005                   6          Gràcia          31
# 4     2023S000006                   6          Gràcia          31
# ...               ...             ...             ...         ...
# 7821  2023S007738                  10      Sant Martí          69
# 7822  2023S007739                   6          Gràcia          32
# 7823  2023S007740                   4       Les Corts          20
# 7824  2023S007741                   4       Les Corts          20
# 7825  2023S007742                   4       Les Corts          20
#
#                                          Nom_barri  Codi_carrer  \
# 0                                            Sants        30602
# ...

# %%
df["Descripcio_tipus_accident"].value_counts()
# Out:
# Descripcio_tipus_accident
# Col.lisió lateral                     1812
# Abast                                 1638
# Col.lisió fronto-lateral              1234
# Atropellament                          930
# Xoc contra element estàtic             653
# Caiguda (dues rodes)                   580
# Caiguda interior vehicle               367
# Abast multiple                         209
# Altres                                 181
# Col.lisió frontal                      143
# Encalç                                  26
# Desconegut                              19
# Xoc amb animal a la calçada             13
# Sortida de via amb xoc o col.lisió      12
# Bolcada (més de dues rodes)              7
# Sortida de via amb bolcada               2
# Name: count, dtype: int64

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 152   2023S000154                   2      Eixample           7
# 153   2023S000154                   2      Eixample           7
# 175   2023S000176                   2      Eixample           9
# 176   2023S000176                   2      Eixample           9
# 249   2023S000249                   4     Les Corts          19
# ...               ...             ...           ...         ...
# 7399  2023S007318                   1  Ciutat Vella           1
# 7483  2023S007402                   2      Eixample           9
# 7484  2023S007402                   2      Eixample           9
# 7671  2023S007589                   2      Eixample           7
# 7672  2023S007589                   2      Eixample           7
#
#                            Nom_barri  Codi_carrer  \
# 152           la Dreta de l'Eixample       145003
# 153           la Dreta de l'Eixample       145003
# ...

# %%
df = df.rename(columns={
    'Coordenada_UTM_X_ED50':"Coordenada_UTM_X",
       'Coordenada_UTM_Y_ED50':"Coordenada_UTM_Y",
         'Longitud_WGS84':"Longitud",
           'Latitud_WGS84':"Latitud"
})
df
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0     2023S000001                   3  Sants-Montjuïc          18
# 1     2023S000002                   7  Horta-Guinardó          33
# 2     2023S000003                   1    Ciutat Vella           1
# 3     2023S000005                   6          Gràcia          31
# 4     2023S000006                   6          Gràcia          31
# ...               ...             ...             ...         ...
# 7821  2023S007738                  10      Sant Martí          69
# 7822  2023S007739                   6          Gràcia          32
# 7823  2023S007740                   4       Les Corts          20
# 7824  2023S007741                   4       Les Corts          20
# 7825  2023S007742                   4       Les Corts          20
#
#                                          Nom_barri  Codi_carrer  \
# 0                                            Sants        30602
# ...

# %%
df["Numero_morts"].value_counts()
# Out:
# Numero_morts
# 0    7800
# 1      26
# Name: count, dtype: int64

# %%
df["Descripcio_tipus_accident"].value_counts()
# Out:
# Descripcio_tipus_accident
# Col.lisió lateral                     1812
# Abast                                 1638
# Col.lisió fronto-lateral              1234
# Atropellament                          930
# Xoc contra element estàtic             653
# Caiguda (dues rodes)                   580
# Caiguda interior vehicle               367
# Abast multiple                         209
# Altres                                 181
# Col.lisió frontal                      143
# Encalç                                  26
# Desconegut                              19
# Xoc amb animal a la calçada             13
# Sortida de via amb xoc o col.lisió      12
# Bolcada (més de dues rodes)              7
# Sortida de via amb bolcada               2
# Name: count, dtype: int64

# %%
df[df["Numero_morts"] != 0]["Descripcio_tipus_accident"].value_counts()
# Out:
# Descripcio_tipus_accident
# Atropellament                         8
# Caiguda interior vehicle              3
# Col.lisió fronto-lateral              3
# Xoc contra element estàtic            3
# Caiguda (dues rodes)                  2
# Col.lisió frontal                     2
# Encalç                                2
# Abast multiple                        1
# Altres                                1
# Sortida de via amb xoc o col.lisió    1
# Name: count, dtype: int64

# %%
df["Descripcio_causa_vianant"].value_counts()
# Out:
# Descripcio_causa_vianant
# No és causa del  vianant           7343
# Desobeir el senyal del semàfor      182
# Creuar per fora pas de vianants     149
# Altres                               96
# Transitar a peu per la calçada       48
# Desobeir altres senyals               8
# Name: count, dtype: int64

# %%
df[df["Numero_morts"] != 0]["Descripcio_causa_vianant"].value_counts()
# Out:
# Descripcio_causa_vianant
# No és causa del  vianant           21
# Desobeir el senyal del semàfor      2
# Creuar per fora pas de vianants     2
# Altres                              1
# Name: count, dtype: int64

# %%
df[df["Numero_morts"] != 0]["Nom_districte"].value_counts()
# Out:
# Nom_districte
# Sant Martí             6
# Ciutat Vella           5
# Eixample               3
# Nou Barris             3
# Sarrià-Sant Gervasi    3
# Gràcia                 2
# Sant Andreu            2
# Horta-Guinardó         2
# Name: count, dtype: int64

# %%
setmana = {"Dilluns":1,
           "Dimarts":2,
           "Dimecres":3,
           "Dijous":4,
           "Divendres":5,
           "Dissabte":6,
           "Diumenge":7
           }
df["Dia_setmana"] = df["Descripcio_dia_setmana"].map(setmana)
df["Descripcio_tipus_dia"] = None

# %%
df["Descripcio_causa_vianant"].value_counts()
# Out:
# Descripcio_causa_vianant
# No és causa del  vianant           7343
# Desobeir el senyal del semàfor      182
# Creuar per fora pas de vianants     149
# Altres                               96
# Transitar a peu per la calçada       48
# Desobeir altres senyals               8
# Name: count, dtype: int64

# %%
df.to_csv("../data/df_2023.csv", index = False)

# %%
import pandas as pd
from datetime import datetime, timedelta
import holidays

# Define el rango de fechas
fecha_inicio = datetime(2010, 1, 1)
fecha_fin = datetime(2025, 12, 31)

# Crea una serie de fechas
dias = pd.date_range(fecha_inicio, fecha_fin)

# Obtiene la lista de festivos de Barcelona
festivos = holidays.CountryHoliday('ES', 'Catalunya')

# Filtra la serie para eliminar los fines de semana y festivos
dias_laborables = dias[~dias.isin(festivos.keys())]
dias_laborables = dias[dias.weekday < 5]

# Convierte la serie a una lista de objetos datetime
lista_dias_laborables = dias_laborables.to_list()

# Imprime la lista de días laborables
print(lista_dias_laborables)
# Out:
# [Timestamp('2010-01-01 00:00:00'), Timestamp('2010-01-04 00:00:00'), Timestamp('2010-01-05 00:00:00'), Timestamp('2010-01-06 00:00:00'), Timestamp('2010-01-07 00:00:00'), Timestamp('2010-01-08 00:00:00'), Timestamp('2010-01-11 00:00:00'), Timestamp('2010-01-12 00:00:00'), Timestamp('2010-01-13 00:00:00'), Timestamp('2010-01-14 00:00:00'), Timestamp('2010-01-15 00:00:00'), Timestamp('2010-01-18 00:00:00'), Timestamp('2010-01-19 00:00:00'), Timestamp('2010-01-20 00:00:00'), Timestamp('2010-01-21 00:00:00'), Timestamp('2010-01-22 00:00:00'), Timestamp('2010-01-25 00:00:00'), Timestamp('2010-01-26 00:00:00'), Timestamp('2010-01-27 00:00:00'), Timestamp('2010-01-28 00:00:00'), Timestamp('2010-01-29 00:00:00'), Timestamp('2010-02-01 00:00:00'), Timestamp('2010-02-02 00:00:00'), Timestamp('2010-02-03 00:00:00'), Timestamp('2010-02-04 00:00:00'), Timestamp('2010-02-05 00:00:00'), Timestamp('2010-02-08 00:00:00'), Timestamp('2010-02-09 00:00:00'), Timestamp('2010-02-10 00:00:00'), Timestamp('
# ...

# %%
df.columns
# Out:
# Index(['Numero_expedient', 'Codi_districte', 'Nom_districte', 'Codi_barri',
#        'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal ',
#        'Descripcio_dia_setmana', 'NK_Any', 'Mes_any', 'Nom_mes', 'Dia_mes',
#        'Hora_dia', 'Descripcio_torn', 'Descripcio_causa_vianant',
#        'Numero_morts', 'Numero_lesionats_lleus', 'Numero_lesionats_greus',
#        'Numero_victimes', 'Numero_vehicles_implicats', 'Coordenada_UTM_Y',
#        'Coordenada_UTM_X', 'Longitud', 'Latitud', 'Descripcio_tipus_accident',
#        'Dia_setmana', 'Descripcio_tipus_dia'],
#       dtype='object')

# %%
df.groupby("Nummero_expedient").aggregate("sum",[])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df.groupby("Nummero_expedient").aggregate("sum",[])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...
