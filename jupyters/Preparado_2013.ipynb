# %% [markdown]
# # Preparación 2014

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2013_ACCIDENTS_GU_BCN_2013.csv", encoding="Windows 1252")
df2 = pd.read_csv("../data/2013_ACCIDENTS_TIPUS_GU_BCN_2013.csv", encoding="cp850")

# %%
df1
# Out:
#      Número d'expedient  Codi districte Nom districte   NK barri  \
# 0           2013S007360              -1    Desconegut   -1--1--1
# 1           2013S007723              10    Sant Martí  101-10-64
# 2           2013S005373              10    Sant Martí  101-10-64
# 3           2013S001486              10    Sant Martí  101-10-64
# 4           2013S008254              10    Sant Martí  101-10-64
# ...                 ...             ...           ...        ...
# 9452        2013S008023               9   Sant Andreu    93-9-59
# 9453        2013S006294               9   Sant Andreu    93-9-59
# 9454        2013S005884               9   Sant Andreu    93-9-59
# 9455        2013S001311               9   Sant Andreu    93-9-59
# 9456        2013S006739               9   Sant Andreu    93-9-59
#
#                        Nom barri  Codi carrer           Nom carrer  \
# 0                     Desconegut           -1           Desconegut
# 1     el Camp de l'Arpa del Clot       152600             Guinardó
# 2     el Camp de l'Arpa del Clot       134801               Freser
# 3     el Camp de l'Arpa del Clot       161407            Indústria
# 4     el Camp de l'Arpa del Clot       161101        Independència
# ...                          ...          ...                  ...
# 9452               el Bon Pastor       701265      Litoral (Besòs)
# 9453               el Bon Pastor       701265      Litoral (Besòs)
# 9454               el Bon Pastor       701266  Litoral (Llobregat)
# 9455               el Bon Pastor        63850              Caracas
# 9456               el Bon Pastor       123306         Ferran Junoy
#
#      Num postal caption Descripció dia setmana  Dia de setmana  ...  \
# 0            Desconegut               Dimecres               3  ...
# 1             0028 0032                Dimarts               2  ...
# 2             0053 0053                Dimarts               2  ...
# 3             0224 0224                Dimarts               2  ...
# 4             0357 0357                Dilluns               1  ...
# ...                 ...                    ...             ...  ...
# 9452          000120000               Diumenge               7  ...
# 9453          000140000                 Dijous               4  ...
# 9454          000110000               Dimecres               3  ...
# 9455         0050B0050B               Dimecres               3  ...
# 9456          0054 0054                Dilluns               1  ...
#
#      Hora de dia  Descripció torn         Descripció causa vianant  \
# 0             21            Tarda                       Desconegut
# 1             21            Tarda                       Desconegut
# 2             10             Matí  Creuar per fora pas de vianants
# 3             10             Matí                           Altres
# 4             16            Tarda                       Desconegut
# ...          ...              ...                              ...
# 9452          18            Tarda                       Desconegut
# 9453          17            Tarda                       Desconegut
# 9454          10             Matí                       Desconegut
# 9455          17            Tarda                       Desconegut
# 9456          10             Matí                       Desconegut
#
#      Número de morts  Número de lesionats lleus  Número de lesionats greus  \
# 0                  0                          1                          0
# 1                  0                          1                          0
# 2                  0                          1                          0
# 3                  0                          1                          0
# 4                  0                          1                          0
# ...              ...                        ...                        ...
# 9452               0                          1                          0
# 9453               0                          2                          0
# 9454               0                          9                          0
# 9455               0                          1                          0
# 9456               0                          2                          0
#
#      Número de víctimes Número de vehicles implicats  Coordenada UTM (Y)  \
# 0                     1                            2                  -1
# 1                     1                            2          4585218,67
# 2                     1                            1          4585049,89
# 3                     1                            1          4584836,20
# 4                     1                            2          4584704,26
# ...                 ...                          ...                 ...
# 9452                  1                            1          4588266,09
# 9453                  2                            3          4588083,71
# 9454                  9                            2          4588339,80
# 9455                  1                            2          4588592,95
# 9456                  2                            2          4588179,93
#
#       Coordenada UTM (X)
# 0                     -1
# 1              431621,41
# 2              431605,09
# 3              431302,26
# 4              431385,76
# ...                  ...
# 9452           433713,00
# 9453           433798,37
# 9454           433640,52
# 9455           433353,63
# 9456           432914,61
#
# [9457 rows x 25 columns]

# %%
df1
# Out:
#      Número d'expedient  Codi districte Nom districte   NK barri  \
# 0           2013S007360              -1    Desconegut   -1--1--1
# 1           2013S007723              10    Sant Martí  101-10-64
# 2           2013S005373              10    Sant Martí  101-10-64
# 3           2013S001486              10    Sant Martí  101-10-64
# 4           2013S008254              10    Sant Martí  101-10-64
# ...                 ...             ...           ...        ...
# 9452        2013S008023               9   Sant Andreu    93-9-59
# 9453        2013S006294               9   Sant Andreu    93-9-59
# 9454        2013S005884               9   Sant Andreu    93-9-59
# 9455        2013S001311               9   Sant Andreu    93-9-59
# 9456        2013S006739               9   Sant Andreu    93-9-59
#
#                        Nom barri  Codi carrer           Nom carrer  \
# 0                     Desconegut           -1           Desconegut
# 1     el Camp de l'Arpa del Clot       152600             Guinardó
# 2     el Camp de l'Arpa del Clot       134801               Freser
# 3     el Camp de l'Arpa del Clot       161407            Indústria
# 4     el Camp de l'Arpa del Clot       161101        Independència
# ...                          ...          ...                  ...
# 9452               el Bon Pastor       701265      Litoral (Besòs)
# 9453               el Bon Pastor       701265      Litoral (Besòs)
# 9454               el Bon Pastor       701266  Litoral (Llobregat)
# 9455               el Bon Pastor        63850              Caracas
# 9456               el Bon Pastor       123306         Ferran Junoy
#
#      Num postal caption Descripció dia setmana  Dia de setmana  ...  \
# 0            Desconegut               Dimecres               3  ...
# 1             0028 0032                Dimarts               2  ...
# 2             0053 0053                Dimarts               2  ...
# 3             0224 0224                Dimarts               2  ...
# 4             0357 0357                Dilluns               1  ...
# ...                 ...                    ...             ...  ...
# 9452          000120000               Diumenge               7  ...
# 9453          000140000                 Dijous               4  ...
# 9454          000110000               Dimecres               3  ...
# 9455         0050B0050B               Dimecres               3  ...
# 9456          0054 0054                Dilluns               1  ...
#
#      Hora de dia  Descripció torn         Descripció causa vianant  \
# 0             21            Tarda                       Desconegut
# 1             21            Tarda                       Desconegut
# 2             10             Matí  Creuar per fora pas de vianants
# 3             10             Matí                           Altres
# 4             16            Tarda                       Desconegut
# ...          ...              ...                              ...
# 9452          18            Tarda                       Desconegut
# 9453          17            Tarda                       Desconegut
# 9454          10             Matí                       Desconegut
# 9455          17            Tarda                       Desconegut
# 9456          10             Matí                       Desconegut
#
#      Número de morts  Número de lesionats lleus  Número de lesionats greus  \
# 0                  0                          1                          0
# 1                  0                          1                          0
# 2                  0                          1                          0
# 3                  0                          1                          0
# 4                  0                          1                          0
# ...              ...                        ...                        ...
# 9452               0                          1                          0
# 9453               0                          2                          0
# 9454               0                          9                          0
# 9455               0                          1                          0
# 9456               0                          2                          0
#
#      Número de víctimes Número de vehicles implicats  Coordenada UTM (Y)  \
# 0                     1                            2                  -1
# 1                     1                            2          4585218,67
# 2                     1                            1          4585049,89
# 3                     1                            1          4584836,20
# 4                     1                            2          4584704,26
# ...                 ...                          ...                 ...
# 9452                  1                            1          4588266,09
# 9453                  2                            3          4588083,71
# 9454                  9                            2          4588339,80
# 9455                  1                            2          4588592,95
# 9456                  2                            2          4588179,93
#
#       Coordenada UTM (X)
# 0                     -1
# 1              431621,41
# 2              431605,09
# 3              431302,26
# 4              431385,76
# ...                  ...
# 9452           433713,00
# 9453           433798,37
# 9454           433640,52
# 9455           433353,63
# 9456           432914,61
#
# [9457 rows x 25 columns]

# %%
df1.columns
# Out:
# Index(['Número d'expedient', 'Codi districte', 'Nom districte', 'NK barri',
#        'Nom barri', 'Codi carrer', 'Nom carrer', 'Num postal caption',
#        'Descripció dia setmana', 'Dia de setmana', 'Descripció tipus dia',
#        'NK Any', 'Mes de any', 'Nom mes', 'Dia de mes', 'Hora de dia',
#        'Descripció torn', 'Descripció causa vianant', 'Número de morts',
#        'Número de lesionats lleus', 'Número de lesionats greus',
#        'Número de víctimes', 'Número de vehicles implicats',
#        'Coordenada UTM (Y)', 'Coordenada UTM (X)'],
#       dtype='object')

# %%
df1 = df1.rename(columns={
    "Número d'expedient": "Numero_expedient",
    "Codi districte": "Codi_districte",
    "Nom districte": "Nom_districte",
    "NK barri": "Codi_barri",
    "Nom barri": "Nom_barri",
    "Codi carrer": "Codi_carrer",
    "Nom carrer": "Nom_carrer",
    "Num postal caption": "Num_postal ",
    "Descripció dia setmana": "Descripcio_dia_setmana",
    "NK Any": "NK_Any",
    "Mes de any": "Mes_any",
    "Nom mes": "Nom_mes",
    "Dia de mes": "Dia_mes",
    "Hora de dia": "Hora_dia",
    "Descripció torn": "Descripcio_torn",
    "Descripció causa vianant": "Descripcio_causa_vianant",
    "Número de morts": "Numero_morts",
    "Número de lesionats lleus": "Numero_lesionats_lleus",
    "Número de lesionats greus": "Numero_lesionats_greus",
    "Número de víctimes": "Numero_victimes",
    "Número de vehicles implicats": "Numero_vehicles_implicats",
    "Coordenada UTM (Y)": "Coordenada_UTM_Y_ED50",
    "Coordenada UTM (X)": "Coordenada_UTM_X_ED50"
})

# %%
df2
# Out:
#       Número d'expedient Codi districte Nom districte Codi barri  \
# 0            2013S009145             10    Sant Martí         64
# 1            2013S006244             10    Sant Martí         64
# 2            2013S000511             10    Sant Martí         64
# 3            2013S009354             10    Sant Martí         64
# 4            2013S001212             10    Sant Martí         64
# ...                  ...            ...           ...        ...
# 10034        2013S008522              9   Sant Andreu         59
# 10035        2013S005935              9   Sant Andreu         59
# 10036        2013S004640              9   Sant Andreu         59
# 10037        2013S003063              9   Sant Andreu         59
# 10038        2013S006183              9   Sant Andreu         58
#
#                         Nom barri Codi carrer           Nom carrer  \
# 0      el Camp de l'Arpa del Clot      209900            Meridiana
# 1      el Camp de l'Arpa del Clot      346402             Trinxant
# 2      el Camp de l'Arpa del Clot      346402             Trinxant
# 3      el Camp de l'Arpa del Clot      194406             Maragall
# 4      el Camp de l'Arpa del Clot      161407            Indústria
# ...                           ...         ...                  ...
# 10034               el Bon Pastor      701265      Litoral (Besòs)
# 10035               el Bon Pastor      701266  Litoral (Llobregat)
# 10036               el Bon Pastor       18902               Arbeca
# 10037               el Bon Pastor      179504                 Lima
# 10038               Baró de Viver      123306         Ferran Junoy
#
#       Num postal caption Descripció dia setmana Dia setmana  \
# 0              0201 0201               Dimecres          Dc
# 1              0027 0027               Dimecres          Dc
# 2              0045 0047                Dimarts          Dm
# 3              0052 0054                Dimarts          Dm
# 4              0257 0257               Dissabte          Ds
# ...                  ...                    ...         ...
# 10034             130000               Dimecres          Dc
# 10035           3,00E+01              Divendres          Dv
# 10036          0019 0019               Dimecres          Dc
# 10037          0011 0011               Dissabte          Ds
# 10038         0056U0056U               Dissabte          Ds
#
#       Descripció tipus dia  NK Any  Mes de any   Nom mes  Dia de mes  \
# 0                  Laboral    2013          12  Desembre          18
# 1                  Laboral    2013           9  Setembre           4
# 2                  Laboral    2013           1     Gener          22
# 3                  Laboral    2013          12  Desembre          24
# 4                  Laboral    2013           2    Febrer          16
# ...                    ...     ...         ...       ...         ...
# 10034              Laboral    2013          11  Novembre          27
# 10035              Laboral    2013           8     Agost          16
# 10036              Laboral    2013           6      Juny          26
# 10037              Laboral    2013           4     Abril          27
# 10038              Laboral    2013           8     Agost          31
#
#        Hora de dia Descripció torn   Descripció tipus accident  \
# 0                8            Matí        Caiguda (dues rodes)
# 1               11            Matí           Col.lisió frontal
# 2               15           Tarda  Xoc contra element estàtic
# 3               20           Tarda           Col.lisió lateral
# 4               13            Matí  Xoc contra element estàtic
# ...            ...             ...                         ...
# 10034           19           Tarda              Abast multiple
# 10035           22             Nit        Caiguda (dues rodes)
# 10036           11            Matí           Col.lisió lateral
# 10037           18           Tarda    Caiguda interior vehicle
# 10038           19           Tarda               Atropellament
#
#       Coordenada UTM (Y) Coordenada UTM (X)
# 0             4585368,61          432116,29
# 1             4585265,29          432053,62
# 2             4585305,49          432014,19
# 3             4585434,72          431625,93
# 4             4585250,74          431554,85
# ...                  ...                ...
# 10034         4588380,51          433851,83
# 10035         4588457,97          433753,46
# 10036         4587839,29          433957,61
# 10037         4588028,25          433629,35
# 10038         4588430,86          433021,42
#
# [10039 rows x 20 columns]

# %%
df2.columns
# Out:
# Index(['Número d'expedient', 'Codi districte', 'Nom districte', 'Codi barri',
#        'Nom barri', 'Codi carrer', 'Nom carrer', 'Num postal caption',
#        'Descripció dia setmana', 'Dia setmana', 'Descripció tipus dia',
#        'NK Any', 'Mes de any', 'Nom mes', 'Dia de mes', 'Hora de dia',
#        'Descripció torn', 'Descripció tipus accident', 'Coordenada UTM (Y)',
#        'Coordenada UTM (X)'],
#       dtype='object')

# %%
df2 = df2.rename(columns={
    "Número d'expedient": "Numero_expedient",
    "Codi districte": "Codi_districte",
    "Nom districte": "Nom_districte",
    "Codi barri": "Codi_barri",
    "Nom barri": "Nom_barri",
    "Codi carrer": "Codi_carrer",
    "Nom carrer": "Nom_carrer",
    "Num postal caption": "Num_postal ",
    "Descripció dia setmana": "Descripcio_dia_setmana",
    'Dia setmana':"Dia_setmana",
    "NK Any":"NK_Any",
    "Mes de any": "Mes_any",
    "Nom mes": "Nom_mes",
    "Dia de mes": "Dia_mes",
    "Hora de dia": "Hora_dia",
    "Descripció torn": "Descripcio_torn",
    "Descripció tipus accident": "Descripcio_tipus_accident",
    "Coordenada UTM (Y)": "Coordenada_UTM_Y_ED50",
    "Coordenada UTM (X)": "Coordenada_UTM_X_ED50"
})

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on="Numero_expedient")

# %%
df
# Out:
#       Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0          2013S007360              -1    Desconegut   -1--1--1
# 1          2013S007723              10    Sant Martí  101-10-64
# 2          2013S005373              10    Sant Martí  101-10-64
# 3          2013S001486              10    Sant Martí  101-10-64
# 4          2013S008254              10    Sant Martí  101-10-64
# ...                ...             ...           ...        ...
# 10034      2013S008023               9   Sant Andreu    93-9-59
# 10035      2013S006294               9   Sant Andreu    93-9-59
# 10036      2013S005884               9   Sant Andreu    93-9-59
# 10037      2013S001311               9   Sant Andreu    93-9-59
# 10038      2013S006739               9   Sant Andreu    93-9-59
#
#                         Nom_barri  Codi_carrer           Nom_carrer  \
# 0                      Desconegut           -1           Desconegut
# 1      el Camp de l'Arpa del Clot       152600             Guinardó
# 2      el Camp de l'Arpa del Clot       134801               Freser
# 3      el Camp de l'Arpa del Clot       161407            Indústria
# 4      el Camp de l'Arpa del Clot       161101        Independència
# ...                           ...          ...                  ...
# 10034               el Bon Pastor       701265      Litoral (Besòs)
# 10035               el Bon Pastor       701265      Litoral (Besòs)
# 10036               el Bon Pastor       701266  Litoral (Llobregat)
# 10037               el Bon Pastor        63850              Caracas
# 10038               el Bon Pastor       123306         Ferran Junoy
#
#       Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 0      Desconegut               Dimecres               3  ...           Tarda
# 1       0028 0032                Dimarts               2  ...           Tarda
# 2       0053 0053                Dimarts               2  ...            Matí
# 3       0224 0224                Dimarts               2  ...            Matí
# 4       0357 0357                Dilluns               1  ...           Tarda
# ...           ...                    ...             ...  ...             ...
# 10034   000120000               Diumenge               7  ...           Tarda
# 10035   000140000                 Dijous               4  ...           Tarda
# 10036   000110000               Dimecres               3  ...            Matí
# 10037  0050B0050B               Dimecres               3  ...           Tarda
# 10038   0054 0054                Dilluns               1  ...            Matí
#
#               Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 0                           Desconegut             0                      1
# 1                           Desconegut             0                      1
# 2      Creuar per fora pas de vianants             0                      1
# 3                               Altres             0                      1
# 4                           Desconegut             0                      1
# ...                                ...           ...                    ...
# 10034                       Desconegut             0                      1
# 10035                       Desconegut             0                      2
# 10036                       Desconegut             0                      9
# 10037                       Desconegut             0                      1
# 10038                       Desconegut             0                      2
#
#        Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 0                           0                1                         2
# 1                           0                1                         2
# 2                           0                1                         1
# 3                           0                1                         1
# 4                           0                1                         2
# ...                       ...              ...                       ...
# 10034                       0                1                         1
# 10035                       0                2                         3
# 10036                       0                9                         2
# 10037                       0                1                         2
# 10038                       0                2                         2
#
#       Coordenada_UTM_Y_ED50  Coordenada_UTM_X_ED50  Descripcio_tipus_accident
# 0                        -1                     -1   Col.lisió fronto-lateral
# 1                4585218,67              431621,41   Col.lisió fronto-lateral
# 2                4585049,89              431605,09              Atropellament
# 3                4584836,20              431302,26              Atropellament
# 4                4584704,26              431385,76                      Abast
# ...                     ...                    ...                        ...
# 10034            4588266,09              433713,00              Atropellament
# 10035            4588083,71              433798,37             Abast multiple
# 10036            4588339,80              433640,52                      Abast
# 10037            4588592,95              433353,63          Col.lisió lateral
# 10038            4588179,93              432914,61                      Abast
#
# [10039 rows x 26 columns]

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 6248      2013S000010              10           Sant Martí  102-10-72
# 6247      2013S000010              10           Sant Martí  102-10-72
# 5909      2013S000023               3       Sants-Montjuïc    32-3-12
# 5908      2013S000023               3       Sants-Montjuïc    32-3-12
# 6679      2013S000054               5  Sarrià-Sant Gervasi    52-5-23
# ...               ...             ...                  ...        ...
# 1386      2013S009363               2             Eixample     24-2-7
# 7830      2013S009451               4            Les Corts    41-4-19
# 7829      2013S009451               4            Les Corts    41-4-19
# 5105      2013S009463               2             Eixample     24-2-7
# 5106      2013S009463               2             Eixample     24-2-7
#
#                        Nom_barri  Codi_carrer             Nom_carrer  \
# 6248    Sant Martí de Provençals         3406            Agricultura
# 6247    Sant Martí de Provençals         3406            Agricultura
# 5909  la Marina del Prat Vermell       374703  Número 50 Zona Franca
# 5908  la Marina del Prat Vermell       374703  Número 50 Zona Franca
# 6679                      Sarrià        46704                 Borràs
# ...                          ...          ...                    ...
# 1386      la Dreta de l'Eixample        32700                 Balmes
# 7830                   les Corts        66508             Carles III
# 7829                   les Corts        66508             Carles III
# 5105      la Dreta de l'Eixample       144601               Diagonal
# 5106      la Dreta de l'Eixample       144601               Diagonal
#
#      Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 6248   0260 0260                Dimarts               2  ...            Matí
# 6247   0260 0260                Dimarts               2  ...            Matí
# 5909   0015 0015               Dimecres               3  ...            Matí
# 5908   0015 0015               Dimecres               3  ...            Matí
# 6679   0006 0006              Divendres               5  ...            Matí
# ...          ...                    ...             ...  ...             ...
# 1386   0112 0112               Dimecres               3  ...            Matí
# 7830   0158 0158                Dilluns               1  ...           Tarda
# 7829   0158 0158                Dilluns               1  ...           Tarda
# 5105   0390 0390                Dimarts               2  ...           Tarda
# 5106   0390 0390                Dimarts               2  ...           Tarda
#
#       Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 6248                Desconegut             0                      1
# 6247                Desconegut             0                      1
# 5909                Desconegut             0                      1
# 5908                Desconegut             0                      1
# 6679                Desconegut             0                      1
# ...                        ...           ...                    ...
# 1386                Desconegut             0                      2
# 7830                Desconegut             0                      1
# 7829                Desconegut             0                      1
# 5105                Desconegut             0                      1
# 5106                Desconegut             0                      1
#
#       Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 6248                       0                1                         2
# 6247                       0                1                         2
# 5909                       0                1                         2
# 5908                       0                1                         2
# 6679                       0                1                         2
# ...                      ...              ...                       ...
# 1386                       0                2                         3
# 7830                       0                1                         2
# 7829                       0                1                         2
# 5105                       0                1                         2
# 5106                       0                1                         2
#
#      Coordenada_UTM_Y_ED50  Coordenada_UTM_X_ED50    Descripcio_tipus_accident
# 6248            4585552,39              433208,92         Caiguda (dues rodes)
# 6247            4585552,39              433208,92     Col.lisió fronto-lateral
# 5909            4576679,33              426035,18            Col.lisió lateral
# 5908            4576679,33              426035,18  Bolcada (més de dues rodes)
# 6679            4583998,05              426189,82   Xoc contra element estàtic
# ...                    ...                    ...                          ...
# 1386            4582697,05              429632,27                        Abast
# 7830            4582633,70              427243,91                        Abast
# 7829            4582633,70              427243,91         Caiguda (dues rodes)
# 5105            4583379,37              430469,69         Caiguda (dues rodes)
# 5106            4583379,37              430469,69                        Abast
#
# [1135 rows x 26 columns]

# %%
df = df.rename(columns={
    'Coordenada_UTM_X_ED50':"Coordenada_UTM_X",
       'Coordenada_UTM_Y_ED50':"Coordenada_UTM_Y",
         'Longitud_WGS84':"Longitud",
           'Latitud_WGS84':"Latitud"
})
df
# Out:
#       Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0          2013S007360              -1    Desconegut   -1--1--1
# 1          2013S007723              10    Sant Martí  101-10-64
# 2          2013S005373              10    Sant Martí  101-10-64
# 3          2013S001486              10    Sant Martí  101-10-64
# 4          2013S008254              10    Sant Martí  101-10-64
# ...                ...             ...           ...        ...
# 10034      2013S008023               9   Sant Andreu    93-9-59
# 10035      2013S006294               9   Sant Andreu    93-9-59
# 10036      2013S005884               9   Sant Andreu    93-9-59
# 10037      2013S001311               9   Sant Andreu    93-9-59
# 10038      2013S006739               9   Sant Andreu    93-9-59
#
#                         Nom_barri  Codi_carrer           Nom_carrer  \
# 0                      Desconegut           -1           Desconegut
# 1      el Camp de l'Arpa del Clot       152600             Guinardó
# 2      el Camp de l'Arpa del Clot       134801               Freser
# 3      el Camp de l'Arpa del Clot       161407            Indústria
# 4      el Camp de l'Arpa del Clot       161101        Independència
# ...                           ...          ...                  ...
# 10034               el Bon Pastor       701265      Litoral (Besòs)
# 10035               el Bon Pastor       701265      Litoral (Besòs)
# 10036               el Bon Pastor       701266  Litoral (Llobregat)
# 10037               el Bon Pastor        63850              Caracas
# 10038               el Bon Pastor       123306         Ferran Junoy
#
#       Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 0      Desconegut               Dimecres               3  ...           Tarda
# 1       0028 0032                Dimarts               2  ...           Tarda
# 2       0053 0053                Dimarts               2  ...            Matí
# 3       0224 0224                Dimarts               2  ...            Matí
# 4       0357 0357                Dilluns               1  ...           Tarda
# ...           ...                    ...             ...  ...             ...
# 10034   000120000               Diumenge               7  ...           Tarda
# 10035   000140000                 Dijous               4  ...           Tarda
# 10036   000110000               Dimecres               3  ...            Matí
# 10037  0050B0050B               Dimecres               3  ...           Tarda
# 10038   0054 0054                Dilluns               1  ...            Matí
#
#               Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 0                           Desconegut             0                      1
# 1                           Desconegut             0                      1
# 2      Creuar per fora pas de vianants             0                      1
# 3                               Altres             0                      1
# 4                           Desconegut             0                      1
# ...                                ...           ...                    ...
# 10034                       Desconegut             0                      1
# 10035                       Desconegut             0                      2
# 10036                       Desconegut             0                      9
# 10037                       Desconegut             0                      1
# 10038                       Desconegut             0                      2
#
#        Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 0                           0                1                         2
# 1                           0                1                         2
# 2                           0                1                         1
# 3                           0                1                         1
# 4                           0                1                         2
# ...                       ...              ...                       ...
# 10034                       0                1                         1
# 10035                       0                2                         3
# 10036                       0                9                         2
# 10037                       0                1                         2
# 10038                       0                2                         2
#
#       Coordenada_UTM_Y  Coordenada_UTM_X  Descripcio_tipus_accident
# 0                   -1                -1   Col.lisió fronto-lateral
# 1           4585218,67         431621,41   Col.lisió fronto-lateral
# 2           4585049,89         431605,09              Atropellament
# 3           4584836,20         431302,26              Atropellament
# 4           4584704,26         431385,76                      Abast
# ...                ...               ...                        ...
# 10034       4588266,09         433713,00              Atropellament
# 10035       4588083,71         433798,37             Abast multiple
# 10036       4588339,80         433640,52                      Abast
# 10037       4588592,95         433353,63          Col.lisió lateral
# 10038       4588179,93         432914,61                      Abast
#
# [10039 rows x 26 columns]

# %%
df["Longitud"] = None
df["Latitud"]= None

# %%
df["Codi_barri"] = df["Codi_barri"].astype(str).str.extract(r'-?(\d+)$')
df
# Out:
#       Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0          2013S007360              -1    Desconegut          1
# 1          2013S007723              10    Sant Martí         64
# 2          2013S005373              10    Sant Martí         64
# 3          2013S001486              10    Sant Martí         64
# 4          2013S008254              10    Sant Martí         64
# ...                ...             ...           ...        ...
# 10034      2013S008023               9   Sant Andreu         59
# 10035      2013S006294               9   Sant Andreu         59
# 10036      2013S005884               9   Sant Andreu         59
# 10037      2013S001311               9   Sant Andreu         59
# 10038      2013S006739               9   Sant Andreu         59
#
#                         Nom_barri  Codi_carrer           Nom_carrer  \
# 0                      Desconegut           -1           Desconegut
# 1      el Camp de l'Arpa del Clot       152600             Guinardó
# 2      el Camp de l'Arpa del Clot       134801               Freser
# 3      el Camp de l'Arpa del Clot       161407            Indústria
# 4      el Camp de l'Arpa del Clot       161101        Independència
# ...                           ...          ...                  ...
# 10034               el Bon Pastor       701265      Litoral (Besòs)
# 10035               el Bon Pastor       701265      Litoral (Besòs)
# 10036               el Bon Pastor       701266  Litoral (Llobregat)
# 10037               el Bon Pastor        63850              Caracas
# 10038               el Bon Pastor       123306         Ferran Junoy
#
#       Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Numero_morts  \
# 0      Desconegut               Dimecres               3  ...            0
# 1       0028 0032                Dimarts               2  ...            0
# 2       0053 0053                Dimarts               2  ...            0
# 3       0224 0224                Dimarts               2  ...            0
# 4       0357 0357                Dilluns               1  ...            0
# ...           ...                    ...             ...  ...          ...
# 10034   000120000               Diumenge               7  ...            0
# 10035   000140000                 Dijous               4  ...            0
# 10036   000110000               Dimecres               3  ...            0
# 10037  0050B0050B               Dimecres               3  ...            0
# 10038   0054 0054                Dilluns               1  ...            0
#
#        Numero_lesionats_lleus  Numero_lesionats_greus Numero_victimes  \
# 0                           1                       0               1
# 1                           1                       0               1
# 2                           1                       0               1
# 3                           1                       0               1
# 4                           1                       0               1
# ...                       ...                     ...             ...
# 10034                       1                       0               1
# 10035                       2                       0               2
# 10036                       9                       0               9
# 10037                       1                       0               1
# 10038                       2                       0               2
#
#        Numero_vehicles_implicats  Coordenada_UTM_Y Coordenada_UTM_X  \
# 0                              2                -1               -1
# 1                              2        4585218,67        431621,41
# 2                              1        4585049,89        431605,09
# 3                              1        4584836,20        431302,26
# 4                              2        4584704,26        431385,76
# ...                          ...               ...              ...
# 10034                          1        4588266,09        433713,00
# 10035                          3        4588083,71        433798,37
# 10036                          2        4588339,80        433640,52
# 10037                          2        4588592,95        433353,63
# 10038                          2        4588179,93        432914,61
#
#       Descripcio_tipus_accident  Longitud  Latitud
# 0      Col.lisió fronto-lateral      None     None
# 1      Col.lisió fronto-lateral      None     None
# 2                 Atropellament      None     None
# 3                 Atropellament      None     None
# 4                         Abast      None     None
# ...                         ...       ...      ...
# 10034             Atropellament      None     None
# 10035            Abast multiple      None     None
# 10036                     Abast      None     None
# 10037         Col.lisió lateral      None     None
# 10038                     Abast      None     None
#
# [10039 rows x 28 columns]

# %%
df.to_csv("../data/df_2013.csv", index = False)

# %%
#df.groupby("Numero_expedient").sum("")
