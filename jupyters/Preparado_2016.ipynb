# %% [markdown]
# # Preparación 2016

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2016_accidents_gu_bcn.csv")
df2 = pd.read_csv("../data/2016_accidents_tipus_gu_bcn_.csv")

# %%
df1
# Out:
#       Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0      2016S001896                  -1    Desconegut          -1
# 1      2016S004886                  -1    Desconegut          -1
# 2      2016S000252                  -1    Desconegut          -1
# 3      2016S000860                  -1    Desconegut          -1
# 4      2016S001165                  -1    Desconegut          -1
# ...                ...             ...           ...         ...
# 10135  2016S004424                   9   Sant Andreu          59
# 10136  2016S007061                   9   Sant Andreu          59
# 10137  2016S007197                   9   Sant Andreu          59
# 10138  2016S000178                   9   Sant Andreu          59
# 10139  2016S003362                   9   Sant Andreu          59
#
#            Nom_barri  Codi_carrer  \
# 0         Desconegut           -1
# 1         Desconegut           -1
# 2         Desconegut           -1
# 3         Desconegut           -1
# 4         Desconegut           -1
# ...              ...          ...
# 10135  el Bon Pastor       331700
# 10136  el Bon Pastor       701204
# 10137  el Bon Pastor       185052
# 10138  el Bon Pastor       318906
# 10139  el Bon Pastor       701204
#
#                                               Nom_carrer  Num_postal  \
# 0      CTRA HTA CERDANY                              ...           1
# 1      FOC / Jocs del 92                             ...         NaN
# 2      CTRA C-58 (RIPOLLE                            ...           0
# 3      NÚMERO 4 / F                                  ...         NaN
# 4      RDA LITORAL(LLOBRE                            ...  K129
# ...                                                  ...         ...
# 10135                                            Tàrrega   0073 0073
# 10136                                           Avançada  0004U0004U
# 10137                                 Llinars del Vallès  0007B0007B
# 10138                                          Santander   0090 0090
# 10139                                           Avançada   0035 0035
#
#       Descripcio_dia_setmana Dia_setmana  ...  Descripcio_causa_vianant  \
# 0                   Dimecres          Dc  ...  No és causa del  vianant
# 1                    Dimarts          Dm  ...  No és causa del  vianant
# 2                    Dimarts          Dm  ...  No és causa del  vianant
# 3                   Dimecres          Dc  ...  No és causa del  vianant
# 4                   Diumenge          Dg  ...  No és causa del  vianant
# ...                      ...         ...  ...                       ...
# 10135                Dimarts          Dm  ...  No és causa del  vianant
# 10136              Divendres          Dv  ...  No és causa del  vianant
# 10137               Dimecres          Dc  ...  No és causa del  vianant
# 10138                 Dijous          Dj  ...  No és causa del  vianant
# 10139                Dimarts          Dm  ...  No és causa del  vianant
#
#        Numero_morts  Numero_lesionats_lleus Numero_lesionats_greus  \
# 0                 0                       0                      0
# 1                 0                       2                      0
# 2                 0                       2                      0
# 3                 0                       1                      0
# 4                 0                       3                      0
# ...             ...                     ...                    ...
# 10135             0                       1                      0
# 10136             0                       1                      0
# 10137             0                       2                      0
# 10138             0                       1                      0
# 10139             0                       1                      0
#
#        Numero_victimes  Numero_vehicles_implicats Coordenada_UTM_X  \
# 0                    0                          1        429369.52
# 1                    2                          2        428989.33
# 2                    2                          4        431940.30
# 3                    1                          2        426830.03
# 4                    3                          4        430583.49
# ...                ...                        ...              ...
# 10135                1                          2        433947.57
# 10136                1                          3        434009.26
# 10137                2                          2        433850.16
# 10138                1                          2        433742.54
# 10139                1                          3        433983.82
#
#       Coordenada_UTM_Y  Longitud    Latitud
# 0           4587865.50  2.153440  41.437411
# 1           4579247.93  2.149901  41.359762
# 2           4590347.92  2.183929  41.459991
# 3           4576250.78  2.124450  41.332574
# 4           4579502.49  2.168929  41.362194
# ...                ...       ...        ...
# 10135       4587888.91  2.208224  41.438003
# 10136       4587689.70  2.208988  41.436216
# 10137       4587564.83  2.207099  41.435077
# 10138       4587203.56  2.205846  41.431817
# 10139       4587667.71  2.208679  41.436016
#
# [10140 rows x 27 columns]

# %%
df2
# Out:
#       Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0      2016S002575                  10    Sant Martí          64
# 1      2016S001146                  10    Sant Martí          64
# 2      2016S009619                  10    Sant Martí          64
# 3      2016S003881                  10    Sant Martí          64
# 4      2016S004162                  10    Sant Martí          64
# ...                ...             ...           ...         ...
# 10696  2016S006620                   9   Sant Andreu          59
# 10697  2016S001747                   9   Sant Andreu          59
# 10698  2016S000092                   9   Sant Andreu          59
# 10699  2016S008885                   9   Sant Andreu          59
# 10700  2016S004039                   9   Sant Andreu          59
#
#                         Nom_barri  Codi_carrer                Nom_carrer  \
# 0      el Camp de l'Arpa del Clot       209900                 Meridiana
# 1      el Camp de l'Arpa del Clot       209900                 Meridiana
# 2      el Camp de l'Arpa del Clot       161407                 Indústria
# 3      el Camp de l'Arpa del Clot       291005            Ruiz de Padrón
# 4      el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# ...                           ...          ...                       ...
# 10696               el Bon Pastor       134007         Fra Juníper Serra
# 10697               el Bon Pastor       134007         Fra Juníper Serra
# 10698               el Bon Pastor       295709                Sant Adrià
# 10699               el Bon Pastor       318906                 Santander
# 10700               el Bon Pastor       318906                 Santander
#
#       Num_postal_caption Descripcio_dia_setmana Dia_setmana  ... Mes_any  \
# 0              0163 0163                Dimarts          Dm  ...       4
# 1              0165 0165               Dissabte          Ds  ...       2
# 2              0303 0303                 Dijous          Dj  ...      12
# 3              0089 0089              Divendres          Dv  ...       5
# 4              0282 0284                Dimarts          Dm  ...       5
# ...                  ...                    ...         ...  ...     ...
# 10696          0077 0077               Dimecres          Dc  ...       8
# 10697          9999 9999              Divendres          Dv  ...       3
# 10698          0056 0056                Dimarts          Dm  ...       1
# 10699          0077 0077              Divendres          Dv  ...      11
# 10700          0110 0110                 Dijous          Dj  ...       5
#
#         Nom_mes  Dia_mes Hora_dia  Descripcio_torn  \
# 0         Abril        5       10             Matí
# 1        Febrer       13       14            Tarda
# 2      Desembre       15        8             Matí
# 3          Maig       20       13             Matí
# 4          Maig       31        0              Nit
# ...         ...      ...      ...              ...
# 10696     Agost       31        8             Matí
# 10697      Març        4       15            Tarda
# 10698     Gener        5       15            Tarda
# 10699  Novembre       18       15            Tarda
# 10700      Maig       26       14            Tarda
#
#         Descripcio_tipus_accident Coordenada_UTM_X Coordenada_UTM_Y  Longitud  \
# 0                           Abast        432111.21       4585072.01  2.186566
# 1               Col.lisió lateral        432111.38       4585084.58  2.186565
# 2                   Atropellament        431846.11       4585523.10  2.183345
# 3      Xoc contra element estàtic        431966.77       4585486.86  2.184785
# 4      Xoc contra element estàtic        431349.11       4585178.66  2.177437
# ...                           ...              ...              ...       ...
# 10696    Col.lisió fronto-lateral        433433.25       4587415.95  2.202124
# 10697                       Abast        433742.97       4587271.92  2.205838
# 10698           Col.lisió lateral        432895.04       4587606.88  2.195664
# 10699           Col.lisió lateral        433642.96       4587108.42  2.204659
# 10700                       Abast        433860.36       4587384.74  2.207238
#
#          Latitud
# 0      41.412487
# 1      41.412595
# 2      41.416527
# 3      41.416204
# 4      41.413377
# ...          ...
# 10696  41.433701
# 10697  41.432429
# 10698  41.435376
# 10699  41.430953
# 10700  41.433457
#
# [10701 rows x 22 columns]

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident",]], how = "inner", on="Numero_expedient")

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#       Numero_expedient  Codi_districte        Nom_districte  Codi_barri  \
# 1646   2016S000004                   2             Eixample           8
# 1647   2016S000004                   2             Eixample           8
# 10388  2016S000024                   5  Sarrià-Sant Gervasi          27
# 10387  2016S000024                   5  Sarrià-Sant Gervasi          27
# 515    2016S000039                   2             Eixample           7
# ...                ...             ...                  ...         ...
# 5136   2016S010014                   7       Horta-Guinardó          40
# 5395   2016S010036                  10           Sant Martí          73
# 5396   2016S010036                  10           Sant Martí          73
# 8883   2016S010127                   4            Les Corts          19
# 8884   2016S010127                   4            Les Corts          19
#
#                              Nom_barri  Codi_carrer           Nom_carrer  \
# 1646   l'Antiga Esquerra de l'Eixample        32700               Balmes
# 1647   l'Antiga Esquerra de l'Eixample        32700               Balmes
# 10388             el Putxet i el Farró       279600  República Argentina
# 10387             el Putxet i el Farró       279600  República Argentina
# 515             la Dreta de l'Eixample       148307               Gràcia
# ...                                ...          ...                  ...
# 5136                           Montbau       352507        Vall d'Hebron
# 5395               la Verneda i la Pau       153205            Guipúscoa
# 5396               la Verneda i la Pau       153205            Guipúscoa
# 8883                         les Corts       231502             Numància
# 8884                         les Corts       231502             Numància
#
#        Num_postal Descripcio_dia_setmana Dia_setmana  ... Numero_morts  \
# 1646    0119 0119              Divendres          Dv  ...            0
# 1647    0119 0119              Divendres          Dv  ...            0
# 10388  0063B0063B               Dissabte          Ds  ...            0
# 10387  0063B0063B               Dissabte          Ds  ...            0
# 515    0019B0019B               Diumenge          Dg  ...            0
# ...           ...                    ...         ...  ...          ...
# 5136   0171A0181A                Dimarts          Dm  ...            0
# 5395    0103 0103               Dimecres          Dc  ...            0
# 5396    0103 0103               Dimecres          Dc  ...            0
# 8883    0048 0050              Divendres          Dv  ...            0
# 8884    0048 0050              Divendres          Dv  ...            0
#
#        Numero_lesionats_lleus  Numero_lesionats_greus Numero_victimes  \
# 1646                        3                       0               3
# 1647                        3                       0               3
# 10388                       1                       0               1
# 10387                       1                       0               1
# 515                         1                       0               1
# ...                       ...                     ...             ...
# 5136                        0                       0               0
# 5395                        1                       0               1
# 5396                        1                       0               1
# 8883                        1                       0               1
# 8884                        1                       0               1
#
#        Numero_vehicles_implicats  Coordenada_UTM_X Coordenada_UTM_Y  Longitud  \
# 1646                           2         429716.06       4582879.74  2.158167
# 1647                           2         429716.06       4582879.74  2.158167
# 10388                          2         428731.08       4584795.01  2.146160
# 10387                          2         428731.08       4584795.01  2.146160
# 515                            2         430444.89       4582603.02  2.166906
# ...                          ...               ...              ...       ...
# 5136                           2         428909.14       4587714.56  2.147946
# 5395                           3         433379.49       4585898.52  2.201645
# 5396                           3         433379.49       4585898.52  2.201645
# 8883                           2         428105.57       4581888.51  2.139017
# 8884                           2         428105.57       4581888.51  2.139017
#
#          Latitud  Descripcio_tipus_accident
# 1646   41.392530          Col.lisió lateral
# 1647   41.392530              Atropellament
# 10388  41.409700   Col.lisió fronto-lateral
# 10387  41.409700       Caiguda (dues rodes)
# 515    41.390107       Caiguda (dues rodes)
# ...          ...                        ...
# 5136   41.436006                     Altres
# 5395   41.420033                     Altres
# 5396   41.420033   Col.lisió fronto-lateral
# 8883   41.383462       Caiguda (dues rodes)
# 8884   41.383462          Col.lisió lateral
#
# [1093 rows x 28 columns]

# %%
df.rename(columns={"Tipus_accident":"Descripcio_tipus_accident"},inplace=True)

# %%
df.to_csv("../data/df_2016.csv", index = False)

# %%
#df.groupby("Numero_expedient").sum("")
