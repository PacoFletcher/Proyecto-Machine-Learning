# %% [markdown]
# # Preparación 2020

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2020_accidents_gu_bcn.csv")
df2 = pd.read_csv("../data/2020_accidents_tipus_gu_bcn.csv")

# %%
df1
# Out:
#      Numero_expedient  Codi_districte   Nom_districte Codi_barri  \
# 0     2020S000001                   7  Horta-Guinardó    72-7-36
# 1     2020S000002                   3  Sants-Montjuïc    33-3-16
# 2     2020S000003                   2        Eixample     23-2-8
# 3     2020S000004                   4       Les Corts    41-4-19
# 4     2020S000005                   2        Eixample     24-2-7
# ...               ...             ...             ...        ...
# 6263  2020S006274                   7  Horta-Guinardó    73-7-37
# 6264  2020S006275                   2        Eixample    21-2-10
# 6265  2020S006276                   1    Ciutat Vella     12-1-2
# 6266  2020S006277                   2        Eixample     22-2-9
# 6267  2020S006278                   8      Nou Barris    84-8-44
#
#                             Nom_barri  Codi_carrer           Nom_carrer  \
# 0                la Font d'en Fargues       194406             Maragall
# 1                          la Bordeta       169409      Corts Catalanes
# 2     l'Antiga Esquerra de l'Eixample       320704               Sarrià
# 3                           les Corts       101904       Doctor Fleming
# 4              la Dreta de l'Eixample       309406            Sant Pere
# ...                               ...          ...                  ...
# 6263                        el Carmel       182600    Lluís Marià Vidal
# 6264                      Sant Antoni       323203            Sepúlveda
# 6265                   el Barri Gòtic       701266  Litoral (Llobregat)
# 6266   la Nova Esquerra de l'Eixample        18505                Aragó
# 6267    Vilapicina i la Torre Llobeta        45701               Quinze
#
#      Num_postal_caption Descripcio_dia_setmana  Dia_setmana  ...  \
# 0             0353 0355               Dimecres            3  ...
# 1             0203 0203               Dimecres            3  ...
# 2             0018 0018               Dimecres            3  ...
# 3             0002 0002               Dimecres            3  ...
# 4             0029 0029               Dimecres            3  ...
# ...                 ...                    ...          ...  ...
# 6263          0025 0025                 Dijous            4  ...
# 6264          0186 0186                 Dijous            4  ...
# 6265            1070000                 Dijous            4  ...
# 6266          0127 0127                 Dijous            4  ...
# 6267          0007 0007                Dimarts            2  ...
#
#             Descripcio_causa_vianant  Numero_morts  Numero_lesionats_lleus  \
# 0                         Desconegut             0                       0
# 1     Desobeir el senyal del semàfor             0                       1
# 2                         Desconegut             0                       2
# 3                         Desconegut             0                       2
# 4                             Altres             0                       1
# ...                              ...           ...                     ...
# 6263                      Desconegut             0                       0
# 6264                      Desconegut             0                       2
# 6265                      Desconegut             0                       2
# 6266                      Desconegut             0                       2
# 6267                      Desconegut             0                       0
#
#      Numero_lesionats_greus  Numero_victimes  Numero_vehicles_implicats  \
# 0                         0                0                          1
# 1                         0                1                          1
# 2                         0                2                          2
# 3                         0                2                          2
# 4                         0                1                          1
# ...                     ...              ...                        ...
# 6263                      0                0                          1
# 6264                      0                2                          2
# 6265                      0                2                          2
# 6266                      0                2                          1
# 6267                      0                0                          2
#
#      Coordenada_UTM_X Coordenada_UTM_Y  Longitud    Latitud
# 0           430501.45       4586751.53  2.167116  41.427474
# 1           428225.71       4580279.72  2.140650  41.368985
# 2           428532.59       4582672.59  2.144037  41.390564
# 3           427929.13       4582767.09  2.136808  41.391361
# 4           431157.87       4582598.57  2.175444  41.390126
# ...               ...              ...       ...        ...
# 6263        429662.80       4586412.97  2.157119  41.424352
# 6264        430125.99       4581881.31  2.163185  41.383577
# 6265        431410.40       4581077.37  2.178636  41.376447
# 6266        429362.84       4581954.15  2.154051  41.384166
# 6267        431221.22       4586654.09  2.175740  41.426658
#
# [6268 rows x 27 columns]

# %%
df2
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0     2020S000001                   7  Horta-Guinardó          36
# 1     2020S000002                   3  Sants-Montjuïc          16
# 2     2020S000003                   2        Eixample           8
# 3     2020S000004                   4       Les Corts          19
# 4     2020S000005                   2        Eixample           7
# ...               ...             ...             ...         ...
# 6575  2020S006274                   7  Horta-Guinardó          37
# 6576  2020S006275                   2        Eixample          10
# 6577  2020S006276                   1    Ciutat Vella           2
# 6578  2020S006277                   2        Eixample           9
# 6579  2020S006278                   8      Nou Barris          44
#
#                             Nom_barri  Codi_carrer           Nom_carrer  \
# 0                la Font d'en Fargues       194406             Maragall
# 1                          la Bordeta       169409      Corts Catalanes
# 2     l'Antiga Esquerra de l'Eixample       320704               Sarrià
# 3                           les Corts       101904       Doctor Fleming
# 4              la Dreta de l'Eixample       309406            Sant Pere
# ...                               ...          ...                  ...
# 6575                        el Carmel       182600    Lluís Marià Vidal
# 6576                      Sant Antoni       323203            Sepúlveda
# 6577                   el Barri Gòtic       701266  Litoral (Llobregat)
# 6578   la Nova Esquerra de l'Eixample        18505                Aragó
# 6579    Vilapicina i la Torre Llobeta        45701               Quinze
#
#      Num_postal_caption Descripcio_dia_setmana Dia_setmana  ... Mes_any  \
# 0             0353 0355               Dimecres          Dc  ...       1
# 1             0203 0203               Dimecres          Dc  ...       1
# 2             0018 0018               Dimecres          Dc  ...       1
# 3             0002 0002               Dimecres          Dc  ...       1
# 4             0029 0029               Dimecres          Dc  ...       1
# ...                 ...                    ...         ...  ...     ...
# 6575          0025 0025                 Dijous          Dj  ...      12
# 6576          0181 0181                 Dijous          Dj  ...      12
# 6577            1070000                 Dijous          Dj  ...      12
# 6578          0127 0127                 Dijous          Dj  ...      12
# 6579          0007 0007                Dimarts          Dm  ...      12
#
#        Nom_mes  Dia_mes Hora_dia  Descripcio_torn   Descripcio_tipus_accident  \
# 0        Gener        1        0              Nit  Xoc contra element estàtic
# 1        Gener        1        2              Nit               Atropellament
# 2        Gener        1        2              Nit           Col.lisió lateral
# 3        Gener        1        6             Matí  Xoc contra element estàtic
# 4        Gener        1        4              Nit               Atropellament
# ...        ...      ...      ...              ...                         ...
# 6575  Desembre       31       17            Tarda  Xoc contra element estàtic
# 6576  Desembre       31       20            Tarda           Col.lisió lateral
# 6577  Desembre       31       13             Matí    Col.lisió fronto-lateral
# 6578  Desembre       31       21            Tarda        Caiguda (dues rodes)
# 6579  Desembre       22       11             Matí  Xoc contra element estàtic
#
#      Coordenada_UTM_X Coordenada_UTM_Y     Longitud    Latitud
# 0           430501,45       4586751,53  2.167115845  41.427474
# 1           428225,71       4580279,72  2.140650262  41.368985
# 2           428532,59       4582672,59  2.144036982  41.390564
# 3           427929,13       4582767,09  2.136808386  41.391361
# 4           431157,87       4582598,57  2.175443819  41.390126
# ...               ...              ...          ...        ...
# 6575         429662,8       4586412,97  2.157119314  41.424352
# 6576        430106,32       4581892,49  2.162948844  41.383676
# 6577         431410,4       4581077,37  2.178636368  41.376447
# 6578        429362,84       4581954,15  2.154050572  41.384166
# 6579        431221,22       4586654,09  2.175740293  41.426658
#
# [6580 rows x 22 columns]

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on = "Numero_expedient")

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 51    2020S000052                   9          Sant Andreu    91-9-63
# 52    2020S000052                   9          Sant Andreu    91-9-63
# 53    2020S000053                   3       Sants-Montjuïc    32-3-13
# 54    2020S000053                   3       Sants-Montjuïc    32-3-13
# 57    2020S000056                   8           Nou Barris    83-8-52
# ...               ...             ...                  ...        ...
# 6335  2020S006028                   5  Sarrià-Sant Gervasi    51-5-26
# 6411  2020S006104                   2             Eixample     23-2-8
# 6412  2020S006104                   2             Eixample     23-2-8
# 6580  2020S006272                   2             Eixample     24-2-7
# 6581  2020S006272                   2             Eixample     24-2-7
#
#                             Nom_barri  Codi_carrer        Nom_carrer  \
# 51                              Navas       115603        Espronceda
# 52                              Navas       115603        Espronceda
# 53                  la Marina de Port       261478           Polvorí
# 54                  la Marina de Port       261478           Polvorí
# 57                     la Prosperitat       701268  Dalt (Llobregat)
# ...                               ...          ...               ...
# 6335           Sant Gervasi - Galvany       144601          Diagonal
# 6411  l'Antiga Esquerra de l'Eixample       268003          Provença
# 6412  l'Antiga Esquerra de l'Eixample       268003          Provença
# 6580           la Dreta de l'Eixample       309406         Sant Pere
# 6581           la Dreta de l'Eixample       309406         Sant Pere
#
#      Num_postal_caption Descripcio_dia_setmana  Dia_setmana  ... Numero_morts  \
# 51            0413 0413               Dissabte            6  ...            0
# 52            0413 0413               Dissabte            6  ...            0
# 53            0003 0003               Dissabte            6  ...            0
# 54            0003 0003               Dissabte            6  ...            0
# 57              1490000               Dissabte            6  ...            0
# ...                 ...                    ...          ...  ...          ...
# 6335          0484 0486                 Dijous            4  ...            0
# 6411          0144 0144               Diumenge            7  ...            0
# 6412          0144 0144               Diumenge            7  ...            0
# 6580          0001 0001                 Dijous            4  ...            0
# 6581          0001 0001                 Dijous            4  ...            0
#
#       Numero_lesionats_lleus  Numero_lesionats_greus Numero_victimes  \
# 51                         1                       0               1
# 52                         1                       0               1
# 53                         1                       0               1
# 54                         1                       0               1
# 57                         2                       0               2
# ...                      ...                     ...             ...
# 6335                       1                       0               1
# 6411                       1                       0               1
# 6412                       1                       0               1
# 6580                       1                       0               1
# 6581                       1                       0               1
#
#       Numero_vehicles_implicats  Coordenada_UTM_X Coordenada_UTM_Y  Longitud  \
# 51                            3         431970.16       4585923.86  2.184785
# 52                            3         431970.16       4585923.86  2.184785
# 53                            3         428405.15       4579740.79  2.142859
# 54                            3         428405.15       4579740.79  2.142859
# 57                            2         431626.51       4588805.26  2.180347
# ...                         ...               ...              ...       ...
# 6335                          3         429463.21       4583230.03  2.155102
# 6411                          2         429196.54       4582322.61  2.152019
# 6412                          2         429196.54       4582322.61  2.152019
# 6580                          2         430741.58       4582396.90  2.170488
# 6581                          2         430741.58       4582396.90  2.170488
#
#         Latitud   Descripcio_tipus_accident
# 51    41.420145           Col.lisió lateral
# 52    41.420145                      Altres
# 53    41.364147                      Altres
# 54    41.364147  Xoc contra element estàtic
# 57    41.446068                      Altres
# ...         ...                         ...
# 6335  41.395667                       Abast
# 6411  41.387470                       Abast
# 6412  41.387470           Col.lisió lateral
# 6580  41.388274    Col.lisió fronto-lateral
# 6581  41.388274           Col.lisió lateral
#
# [642 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Numero_expedient', 'Codi_districte', 'Nom_districte', 'Codi_barri',
#        'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal_caption',
#        'Descripcio_dia_setmana', 'Dia_setmana', 'Descripcio_tipus_dia',
#        'NK_Any', 'Mes_any', 'Nom_mes', 'Dia_mes', 'Hora_dia',
#        'Descripcio_torn', 'Descripcio_causa_vianant', 'Numero_morts',
#        'Numero_lesionats_lleus', 'Numero_lesionats_greus', 'Numero_victimes',
#        'Numero_vehicles_implicats', 'Coordenada_UTM_X', 'Coordenada_UTM_Y',
#        'Longitud', 'Latitud', 'Descripcio_tipus_accident'],
#       dtype='object')

# %%
df.to_csv("../data/df_2020.csv", index = False)

# %%
#df.groupby("Numero_expedient").sum("")
