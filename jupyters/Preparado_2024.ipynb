# %% [markdown]
# # Procesamiento y análisis de datos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("../data/2024_accidents_gu_bcn.csv")
df2 = pd.read_csv("../data/2024_accidents_tipus_gu_bcn.csv")

# %%
df2
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0         2024S000001               9     Sant Andreu          57
# 1         2024S000002               2        Eixample           8
# 2         2024S000003               2        Eixample          10
# 3         2024S000004               1    Ciutat Vella           2
# 4         2024S000005               4       Les Corts          19
# ...               ...             ...             ...         ...
# 7532      2024S007546               9     Sant Andreu          59
# 7533      2024S007547               2        Eixample           7
# 7534      2024S007548               1    Ciutat Vella           4
# 7535      2024S007549               3  Sants-Montjuïc          11
# 7536      2024S007550               3  Sants-Montjuïc          11
#
#                                   Nom_barri  Codi_carrer  \
# 0                         la Trinitat Vella     701268.0
# ...

# %%
df1
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0         2024S000001               9     Sant Andreu          57
# 1         2024S000002               2        Eixample           8
# 2         2024S000003               2        Eixample          10
# 3         2024S000004               1    Ciutat Vella           2
# 4         2024S000005               4       Les Corts          19
# ...               ...             ...             ...         ...
# 7531      2024S007547               2        Eixample           7
# 7532      2024S007548               1    Ciutat Vella           4
# 7533      2024S007549               3  Sants-Montjuïc          11
# 7534      2024S007550               3  Sants-Montjuïc          11
# 7535      2024S007551               1    Ciutat Vella           1
#
#                                   Nom_barri  Codi_carrer  \
# 0                         la Trinitat Vella       701268
# ...

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on="Numero_expedient",)
df
# Out:
#      Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0         2024S000001               9     Sant Andreu          57
# 1         2024S000002               2        Eixample           8
# 2         2024S000003               2        Eixample          10
# 3         2024S000004               1    Ciutat Vella           2
# 4         2024S000005               4       Les Corts          19
# ...               ...             ...             ...         ...
# 7530      2024S007546               9     Sant Andreu          59
# 7531      2024S007547               2        Eixample           7
# 7532      2024S007548               1    Ciutat Vella           4
# 7533      2024S007549               3  Sants-Montjuïc          11
# 7534      2024S007550               3  Sants-Montjuïc          11
#
#                                   Nom_barri  Codi_carrer  \
# 0                         la Trinitat Vella       701268
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Numero_expedient, Codi_districte, Nom_districte, Codi_barri, Nom_barri, Codi_carrer, Nom_carrer, Num_postal , Descripcio_dia_setmana, NK_Any, Mes_any, Nom_mes, Dia_mes, Hora_dia, Descripcio_torn, Descripcio_causa_vianant, Numero_morts, Numero_lesionats_lleus, Numero_lesionats_greus, Numero_victimes, Numero_vehicles_implicats, Coordenada_UTM_Y_ED50, Coordenada_UTM_X_ED50, Longitud_WGS84, Latitud_WGS84, Descripcio_tipus_accident]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7538 entries, 0 to 7537
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           7538 non-null   object
#  1   Codi_districte             7536 non-null   float64
#  2   Nom_districte              7536 non-null   object
#  3   Codi_barri                 7536 non-null   float64
#  4   Nom_barri                  7536 non-null   object
#  5   Codi_carrer                7536 non-null   float64
#  6   Nom_carrer                 7536 non-null   object
#  7   Num_postal                 4425 non-null   object
#  8   Descripcio_dia_setmana     7536 non-null   object
#  9   NK_Any                     7536 non-null   float64
#  10  Mes_any                    7536 non-null   float64
#  11  Nom_mes                    7536 non-null   object
#  12  Dia_mes                    7536 non-null   float64
# ...

# %%
df["Descripcio_tipus_accident"].value_counts()
# Out:
# Descripcio_tipus_accident
# Col.lisió lateral                     1689
# Abast                                 1643
# Col.lisió fronto-lateral              1209
# Atropellament                          883
# Xoc contra element estàtic             645
# Caiguda (dues rodes)                   490
# Caiguda interior vehicle               405
# Abast multiple                         204
# Altres                                 163
# Col.lisió frontal                      114
# Encalç                                  45
# Bolcada (més de dues rodes)             18
# Sortida de via amb xoc o col.lisió      14
# Xoc amb animal a la calçada              8
# Sortida de via amb bolcada               2
# Resta sortides de via                    2
# Name: count, dtype: int64

# %%
df["Nom_districte"].value_counts()
# Out:
# Nom_districte
# Eixample               1898
# Sant Martí              948
# Sants-Montjuïc          856
# Sarrià-Sant Gervasi     805
# Horta-Guinardó          637
# Les Corts               548
# Sant Andreu             508
# Nou Barris              484
# Gràcia                  429
# Ciutat Vella            423
# Name: count, dtype: int64

# %%
df[(df["Nom_districte"] == "Eixample") & (df["Numero_morts"].notna())]
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 3222      2024S003233             2.0      Eixample         8.0
#
#                             Nom_barri  Codi_carrer Nom_carrer Num_postal   \
# 3222  l'Antiga Esquerra de l'Eixample     100800.0  Diputació         225
#
#      Descripcio_dia_setmana  NK_Any  ...  Numero_morts Numero_lesionats_lleus  \
# 3222               Dimecres  2024.0  ...           1.0                    NaN
#
#       Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 3222                     NaN              1.0                       4.0
#
#      Coordenada_UTM_Y_ED50  Coordenada_UTM_X_ED50  Longitud_WGS84  \
# 3222             430073.22            4582275.663        2.162509
#
#       Latitud_WGS84  Descripcio_tipus_accident
# 3222      41.387124                     Encalç
#
# [1 rows x 26 columns]

# %%
df[df["Descripcio_tipus_accident"].isna()]
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 2899      2024S002908             6.0        Gràcia        28.0
# 5243      2024S005255             NaN           NaN         NaN
# 6017      2024S006031             NaN           NaN         NaN
# 7537      2024S007551             1.0  Ciutat Vella         1.0
#
#                       Nom_barri  Codi_carrer Nom_carrer Num_postal   \
# 2899  Vallcarca i els Penitents       3508.0     Aigües         400
# 5243                        NaN          NaN        NaN         NaN
# 6017                        NaN          NaN        NaN         NaN
# 7537                   el Raval     701367.0      Raval         25X
#
#      Descripcio_dia_setmana  NK_Any  ...  Numero_morts Numero_lesionats_lleus  \
# 2899                Dimarts  2024.0  ...           NaN                    1.0
# 5243                    NaN     NaN  ...           NaN                    NaN
# ...
