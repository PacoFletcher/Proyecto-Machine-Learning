# %% [markdown]
# # Preparación 2021

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2021_accidents_gu_bcn.csv")
df2 = pd.read_csv("../data/2021_accidents_tipus_gu_bcn.csv")

# %%
df1
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0     2021S002939                  -1    Desconegut          -1
# 1     2021S004839                  -1    Desconegut          -1
# 2     2021S000882                  10    Sant Martí          64
# 3     2021S001565                  10    Sant Martí          64
# 4     2021S001798                  10    Sant Martí          64
# ...               ...             ...           ...         ...
# 7654  2021S006169                   8    Nou Barris          44
# 7655  2021S002684                   9   Sant Andreu          61
# 7656  2021S004117                   8    Nou Barris          44
# 7657  2021S005061                   8    Nou Barris          44
# 7658  2021S002530                   8    Nou Barris          45
#
#                           Nom_barri  Codi_carrer  \
# 0                        Desconegut           -1
# 1                        Desconegut           -1
# ...

# %%
df2
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0     2021S006247                  -1    Desconegut          -1
# 1     2021S000858                  -1    Desconegut          -1
# 2     2021S004053                  10    Sant Martí          64
# 3     2021S004166                  10    Sant Martí          64
# 4     2021S005696                  10    Sant Martí          64
# ...               ...             ...           ...         ...
# 7791  2021S001025                   8    Nou Barris          44
# 7792  2021S001387                   8    Nou Barris          45
# 7793  2021S002364                   8    Nou Barris          45
# 7794  2021S007426                   8    Nou Barris          45
# 7795  2021S001116                   8    Nou Barris          44
#
#                           Nom_barri  Codi_carrer  \
# 0                        Desconegut           -1
# 1                        Desconegut           -1
# ...

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on = "Numero_expedient")

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte        Nom_districte  Codi_barri  \
# 6441  2021S000051                   4            Les Corts          20
# 6442  2021S000051                   4            Les Corts          20
# 7209  2021S000055                   2             Eixample           6
# 7208  2021S000055                   2             Eixample           6
# 6759  2021S000113                   8           Nou Barris          53
# ...               ...             ...                  ...         ...
# 5541  2021S007397                   5  Sarrià-Sant Gervasi          23
# 4756  2021S007498                   9          Sant Andreu          62
# 4755  2021S007498                   9          Sant Andreu          62
# 6729  2021S007527                   7       Horta-Guinardó          35
# 6728  2021S007527                   7       Horta-Guinardó          35
#
#                        Nom_barri  Codi_carrer        Nom_carrer  \
# ...

# %%
df
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0     2021S002939                  -1    Desconegut          -1
# 1     2021S004839                  -1    Desconegut          -1
# 2     2021S000882                  10    Sant Martí          64
# 3     2021S001565                  10    Sant Martí          64
# 4     2021S001798                  10    Sant Martí          64
# ...               ...             ...           ...         ...
# 7797  2021S006169                   8    Nou Barris          44
# 7798  2021S002684                   9   Sant Andreu          61
# 7799  2021S004117                   8    Nou Barris          44
# 7800  2021S005061                   8    Nou Barris          44
# 7801  2021S002530                   8    Nou Barris          45
#
#                           Nom_barri  Codi_carrer  \
# 0                        Desconegut           -1
# 1                        Desconegut           -1
# ...

# %%
df.columns
# Out:
# Index(['Numero_expedient', 'Codi_districte', 'Nom_districte', 'Codi_barri',
#        'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal_caption',
#        'Descripcio_dia_setmana', 'NK_Any', 'Mes_any', 'Nom_mes', 'Dia_mes',
#        'Hora_dia', 'Descripcio_torn', 'Descripcio_causa_vianant',
#        'Numero_morts', 'Numero_lesionats_lleus', 'Numero_lesionats_greus',
#        'Numero_victimes', 'Numero_vehicles_implicats', 'Coordenada_UTM_X_ED50',
#        'Coordenada_UTM_Y_ED50', 'Longitud_WGS84', 'Latitud_WGS84',
#        'Descripcio_tipus_accident'],
#       dtype='object')

# %%
lista = ['Numero_expedient', 'Codi_districte', 'Nom_districte', 'Codi_barri',
       'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal_caption',
       'Descripcio_dia_setmana', 'Dia_setmana', 'Descripcio_tipus_dia',
       'NK_Any', 'Mes_any', 'Nom_mes', 'Dia_mes', 'Hora_dia',
       'Descripcio_torn', 'Descripcio_causa_vianant', 'Numero_morts',
       'Numero_lesionats_lleus', 'Numero_lesionats_greus', 'Numero_victimes',
       'Numero_vehicles_implicats', 'Coordenada_UTM_X', 'Coordenada_UTM_Y',
       'Longitud', 'Latitud', 'Descripcio_tipus_accident']
lista
# Out:
# ['Numero_expedient',
#  'Codi_districte',
#  'Nom_districte',
#  'Codi_barri',
#  'Nom_barri',
#  'Codi_carrer',
#  'Nom_carrer',
#  'Num_postal_caption',
#  'Descripcio_dia_setmana',
#  'Dia_setmana',
#  'Descripcio_tipus_dia',
#  'NK_Any',
#  'Mes_any',
#  'Nom_mes',
#  'Dia_mes',
#  'Hora_dia',
#  'Descripcio_torn',
#  'Descripcio_causa_vianant',
#  'Numero_morts',
#  'Numero_lesionats_lleus',
#  'Numero_lesionats_greus',
#  'Numero_victimes',
#  'Numero_vehicles_implicats',
#  'Coordenada_UTM_X',
#  'Coordenada_UTM_Y',
#  'Longitud',
#  'Latitud',
#  'Descripcio_tipus_accident']

# %%
df.columns.isin(lista)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False, False, False,  True])

# %%
df = df.rename(columns={
    'Coordenada_UTM_X_ED50':"Coordenada_UTM_X",
       'Coordenada_UTM_Y_ED50':"Coordenada_UTM_Y",
         'Longitud_WGS84':"Longitud",
           'Latitud_WGS84':"Latitud"
})
df
# Out:
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0     2021S002939                  -1    Desconegut          -1
# 1     2021S004839                  -1    Desconegut          -1
# 2     2021S000882                  10    Sant Martí          64
# 3     2021S001565                  10    Sant Martí          64
# 4     2021S001798                  10    Sant Martí          64
# ...               ...             ...           ...         ...
# 7797  2021S006169                   8    Nou Barris          44
# 7798  2021S002684                   9   Sant Andreu          61
# 7799  2021S004117                   8    Nou Barris          44
# 7800  2021S005061                   8    Nou Barris          44
# 7801  2021S002530                   8    Nou Barris          45
#
#                           Nom_barri  Codi_carrer  \
# 0                        Desconegut           -1
# 1                        Desconegut           -1
# ...

# %%
df.columns.isin(lista)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
setmana = {"Dilluns":1,
           "Dimarts":2,
           "Dimecres":3,
           "Dijous":4,
           "Divendres":5,
           "Dissabte":6,
           "Diumenge":7
           }
df["Dia_setmana"] = df["Descripcio_dia_setmana"].map(setmana)
df["Descripcio_tipus_dia"] = None

# %%
df.to_csv("../data/df_2021.csv", index = False)

# %%
#df.groupby("Numero_expedient").sum("")
