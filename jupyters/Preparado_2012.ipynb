# %% [markdown]
# # Preparación 2014

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2012_ACCIDENTS_GU_BCN_2012.csv", encoding="Windows 1252")
df2 = pd.read_csv("../data/2012_ACCIDENTS_TIPUS_GU_BCN_2012.csv", encoding="cp850")

# %%
df1
# Out:
#      Número d'expedient  Codi districte Nom districte   NK barri  \
# 0           2012S005688              10    Sant Martí  101-10-64
# 1           2012S005343              10    Sant Martí  101-10-64
# 2           2012S002291              10    Sant Martí  101-10-64
# 3           2012S005379              10    Sant Martí  101-10-64
# 4           2012S004837              10    Sant Martí  101-10-64
# ...                 ...             ...           ...        ...
# 9248        2012S006787               9   Sant Andreu    93-9-59
# 9249        2012S004375               9   Sant Andreu    93-9-59
# 9250        2012S000898               9   Sant Andreu    93-9-59
# 9251        2012S002266               9   Sant Andreu    93-9-59
# 9252        2012S008119               9   Sant Andreu    93-9-59
#
#                        Nom barri  Codi carrer                Nom carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# 1     el Camp de l'Arpa del Clot       226400       Las Navas de Tolosa
# 2     el Camp de l'Arpa del Clot       161407                 Indústria
# 3     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# ...                          ...          ...                       ...
# 9248               el Bon Pastor       295709                Sant Adrià
# 9249               el Bon Pastor       148908                Granadella
# 9250               el Bon Pastor       264308                    Potosí
# 9251               el Bon Pastor       347551                   Tucumán
# 9252               el Bon Pastor       701265           Litoral (Besòs)
#
#      Num postal caption Descripció dia setmana  Dia de setmana  ...  \
# 0             0203 0205               Dissabte               6  ...
# 1             0337 0337               Diumenge               7  ...
# 2             0288 0288                 Dijous               4  ...
# 3             0356 0356                Dimarts               2  ...
# 4             0270 0270                Dimarts               2  ...
# ...                 ...                    ...             ...  ...
# 9248          0109 0109              Divendres               5  ...
# 9249          0058 0058               Diumenge               7  ...
# 9250          0003 0003                Dimarts               2  ...
# 9251          0030 0030               Dimecres               3  ...
# 9252          000120000                Dilluns               1  ...
#
#      Hora de dia  Descripció torn         Descripció causa vianant  \
# 0             16            Tarda                       Desconegut
# 1             21            Tarda                       Desconegut
# 2             15            Tarda                       Desconegut
# 3             10             Matí  Creuar per fora pas de vianants
# 4             14            Tarda                       Desconegut
# ...          ...              ...                              ...
# 9248           6             Matí                       Desconegut
# 9249           1              Nit                       Desconegut
# 9250          13             Matí                       Desconegut
# 9251          17            Tarda                       Desconegut
# 9252          21            Tarda                       Desconegut
#
#      Número de morts  Número de lesionats lleus  Número de lesionats greus  \
# 0                  0                          1                          0
# 1                  0                          1                          0
# 2                  0                          1                          0
# 3                  0                          2                          0
# 4                  0                          2                          0
# ...              ...                        ...                        ...
# 9248               0                          1                          0
# 9249               0                          0                          0
# 9250               0                          1                          0
# 9251               0                          2                          0
# 9252               0                          1                          0
#
#      Número de víctimes Número de vehicles implicats  Coordenada UTM (Y)  \
# 0                     1                            2          4585178,54
# 1                     1                            2          4585352,36
# 2                     1                            2          4585102,28
# 3                     2                            1          4585266,01
# 4                     2                            1          4584898,92
# ...                 ...                          ...                 ...
# 9248                  1                            2          4587491,96
# 9249                  0                            1          4587733,68
# 9250                  1                            2          4588245,96
# 9251                  2                            3          4588644,80
# 9252                  1                            2          4588266,09
#
#       Coordenada UTM (X)
# 0              432022,72
# 1              431860,84
# 2              431556,72
# 3              431552,73
# 4              431180,43
# ...                  ...
# 9248           433538,26
# 9249           433790,15
# 9250           433206,25
# 9251           433417,16
# 9252           433713,00
#
# [9253 rows x 25 columns]

# %%
df1
# Out:
#      Número d'expedient  Codi districte Nom districte   NK barri  \
# 0           2012S005688              10    Sant Martí  101-10-64
# 1           2012S005343              10    Sant Martí  101-10-64
# 2           2012S002291              10    Sant Martí  101-10-64
# 3           2012S005379              10    Sant Martí  101-10-64
# 4           2012S004837              10    Sant Martí  101-10-64
# ...                 ...             ...           ...        ...
# 9248        2012S006787               9   Sant Andreu    93-9-59
# 9249        2012S004375               9   Sant Andreu    93-9-59
# 9250        2012S000898               9   Sant Andreu    93-9-59
# 9251        2012S002266               9   Sant Andreu    93-9-59
# 9252        2012S008119               9   Sant Andreu    93-9-59
#
#                        Nom barri  Codi carrer                Nom carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# 1     el Camp de l'Arpa del Clot       226400       Las Navas de Tolosa
# 2     el Camp de l'Arpa del Clot       161407                 Indústria
# 3     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# ...                          ...          ...                       ...
# 9248               el Bon Pastor       295709                Sant Adrià
# 9249               el Bon Pastor       148908                Granadella
# 9250               el Bon Pastor       264308                    Potosí
# 9251               el Bon Pastor       347551                   Tucumán
# 9252               el Bon Pastor       701265           Litoral (Besòs)
#
#      Num postal caption Descripció dia setmana  Dia de setmana  ...  \
# 0             0203 0205               Dissabte               6  ...
# 1             0337 0337               Diumenge               7  ...
# 2             0288 0288                 Dijous               4  ...
# 3             0356 0356                Dimarts               2  ...
# 4             0270 0270                Dimarts               2  ...
# ...                 ...                    ...             ...  ...
# 9248          0109 0109              Divendres               5  ...
# 9249          0058 0058               Diumenge               7  ...
# 9250          0003 0003                Dimarts               2  ...
# 9251          0030 0030               Dimecres               3  ...
# 9252          000120000                Dilluns               1  ...
#
#      Hora de dia  Descripció torn         Descripció causa vianant  \
# 0             16            Tarda                       Desconegut
# 1             21            Tarda                       Desconegut
# 2             15            Tarda                       Desconegut
# 3             10             Matí  Creuar per fora pas de vianants
# 4             14            Tarda                       Desconegut
# ...          ...              ...                              ...
# 9248           6             Matí                       Desconegut
# 9249           1              Nit                       Desconegut
# 9250          13             Matí                       Desconegut
# 9251          17            Tarda                       Desconegut
# 9252          21            Tarda                       Desconegut
#
#      Número de morts  Número de lesionats lleus  Número de lesionats greus  \
# 0                  0                          1                          0
# 1                  0                          1                          0
# 2                  0                          1                          0
# 3                  0                          2                          0
# 4                  0                          2                          0
# ...              ...                        ...                        ...
# 9248               0                          1                          0
# 9249               0                          0                          0
# 9250               0                          1                          0
# 9251               0                          2                          0
# 9252               0                          1                          0
#
#      Número de víctimes Número de vehicles implicats  Coordenada UTM (Y)  \
# 0                     1                            2          4585178,54
# 1                     1                            2          4585352,36
# 2                     1                            2          4585102,28
# 3                     2                            1          4585266,01
# 4                     2                            1          4584898,92
# ...                 ...                          ...                 ...
# 9248                  1                            2          4587491,96
# 9249                  0                            1          4587733,68
# 9250                  1                            2          4588245,96
# 9251                  2                            3          4588644,80
# 9252                  1                            2          4588266,09
#
#       Coordenada UTM (X)
# 0              432022,72
# 1              431860,84
# 2              431556,72
# 3              431552,73
# 4              431180,43
# ...                  ...
# 9248           433538,26
# 9249           433790,15
# 9250           433206,25
# 9251           433417,16
# 9252           433713,00
#
# [9253 rows x 25 columns]

# %%
df1.columns
# Out:
# Index(['Número d'expedient', 'Codi districte', 'Nom districte', 'NK barri',
#        'Nom barri', 'Codi carrer', 'Nom carrer', 'Num postal caption',
#        'Descripció dia setmana', 'Dia de setmana', 'Descripció tipus dia',
#        'NK Any', 'Mes de any', 'Nom mes', 'Dia de mes', 'Hora de dia',
#        'Descripció torn', 'Descripció causa vianant', 'Número de morts',
#        'Número de lesionats lleus', 'Número de lesionats greus',
#        'Número de víctimes', 'Número de vehicles implicats',
#        'Coordenada UTM (Y)', 'Coordenada UTM (X)'],
#       dtype='object')

# %%
df1 = df1.rename(columns={
    "Número d'expedient": "Numero_expedient",
    "Codi districte": "Codi_districte",
    "Nom districte": "Nom_districte",
    "NK barri": "Codi_barri",
    "Nom barri": "Nom_barri",
    "Codi carrer": "Codi_carrer",
    "Nom carrer": "Nom_carrer",
    "Num postal caption": "Num_postal ",
    "Descripció dia setmana": "Descripcio_dia_setmana",
    "NK Any": "NK_Any",
    "Mes de any": "Mes_any",
    "Nom mes": "Nom_mes",
    "Dia de mes": "Dia_mes",
    "Hora de dia": "Hora_dia",
    "Descripció torn": "Descripcio_torn",
    "Descripció causa vianant": "Descripcio_causa_vianant",
    "Número de morts": "Numero_morts",
    "Número de lesionats lleus": "Numero_lesionats_lleus",
    "Número de lesionats greus": "Numero_lesionats_greus",
    "Número de víctimes": "Numero_victimes",
    "Número de vehicles implicats": "Numero_vehicles_implicats",
    "Coordenada UTM (Y)": "Coordenada_UTM_Y_ED50",
    "Coordenada UTM (X)": "Coordenada_UTM_X_ED50"
})

# %%
df2
# Out:
#      Número d'expedient Codi districte Nom districte Codi barri  \
# 0           2012S005688             10    Sant Martí         64
# 1           2012S002763             10    Sant Martí         64
# 2           2012S007349             10    Sant Martí         64
# 3           2012S003847             10    Sant Martí         64
# 4           2012S009254             10    Sant Martí         64
# ...                 ...            ...           ...        ...
# 9814        2012S005002              9   Sant Andreu         59
# 9815        2012S008561              9   Sant Andreu         59
# 9816        2012S005771              9   Sant Andreu         59
# 9817        2012S008931              9   Sant Andreu         59
# 9818        2012S007067              9   Sant Andreu         59
#
#                        Nom barri Codi carrer       Nom carrer  \
# 0     el Camp de l'Arpa del Clot      209900        Meridiana
# 1     el Camp de l'Arpa del Clot      194406         Maragall
# 2     el Camp de l'Arpa del Clot      367402           Volart
# 3     el Camp de l'Arpa del Clot      161407        Indústria
# 4     el Camp de l'Arpa del Clot      134801           Freser
# ...                          ...         ...              ...
# 9814               el Bon Pastor      701265  Litoral (Besòs)
# 9815               el Bon Pastor      151957        Guayaquil
# 9816               el Bon Pastor      151957        Guayaquil
# 9817               el Bon Pastor      151957        Guayaquil
# 9818               el Bon Pastor        8400         Alfarràs
#
#      Num postal caption Descripció dia setmana Dia setmana  \
# 0             0203 0205               Dissabte          Ds
# 1             0045 0045               Dimecres          Dc
# 2             0001 0001               Dissabte          Ds
# 3             0213 0213                Dimarts          Dm
# 4             0064 0064                Dilluns          Dl
# ...                 ...                    ...         ...
# 9814          0030S0000                Dilluns          Dl
# 9815          0001 0005                Dimarts          Dm
# 9816          0009 0009                 Dijous          Dj
# 9817          0039 0039                Dimarts          Dm
# 9818          0026 0026                Dilluns          Dl
#
#      Descripció tipus dia  NK Any  Mes de any   Nom mes  Dia de mes  \
# 0                 Laboral    2012           8     Agost           4
# 1                 Laboral    2012           4     Abril          18
# 2                 Laboral    2012          10   Octubre          20
# 3                 Laboral    2012           5      Maig          29
# 4                 Laboral    2012          12  Desembre          31
# ...                   ...     ...         ...       ...         ...
# 9814              Laboral    2012           7    Juliol           9
# 9815              Laboral    2012          12  Desembre           4
# 9816              Laboral    2012           8     Agost           9
# 9817              Laboral    2012          12  Desembre          18
# 9818              Laboral    2012          10   Octubre           8
#
#       Hora de dia Descripció torn   Descripció tipus accident  \
# 0              16           Tarda    Col.lisió fronto-lateral
# 1              15           Tarda           Col.lisió lateral
# 2               9            Matí                       Abast
# 3              12            Matí              Abast multiple
# 4               9            Matí    Col.lisió fronto-lateral
# ...           ...             ...                         ...
# 9814           16           Tarda              Abast multiple
# 9815           13            Matí              Abast multiple
# 9816           11            Matí  Xoc contra element estàtic
# 9817           14           Tarda           Col.lisió lateral
# 9818           20           Tarda           Col.lisió lateral
#
#      Coordenada UTM (Y) Coordenada UTM (X)
# 0            4585382,72          432116,48
# 1            4585404,32           431598,8
# 2            4585406,24          431594,76
# 3            4585002,66          431325,76
# 4            4584964,87          431585,78
# ...                 ...                ...
# 9814         4588355,65          433863,66
# 9815         4588121,66          433905,55
# 9816         4588218,15          433877,14
# 9817         4588678,66          433625,82
# 9818         4587833,78           433684,2
#
# [9819 rows x 20 columns]

# %%
df2.columns
# Out:
# Index(['Número d'expedient', 'Codi districte', 'Nom districte', 'Codi barri',
#        'Nom barri', 'Codi carrer', 'Nom carrer', 'Num postal caption',
#        'Descripció dia setmana', 'Dia setmana', 'Descripció tipus dia',
#        'NK Any', 'Mes de any', 'Nom mes', 'Dia de mes', 'Hora de dia',
#        'Descripció torn', 'Descripció tipus accident', 'Coordenada UTM (Y)',
#        'Coordenada UTM (X)'],
#       dtype='object')

# %%
df2 = df2.rename(columns={
    "Número d'expedient": "Numero_expedient",
    "Codi districte": "Codi_districte",
    "Nom districte": "Nom_districte",
    "Codi barri": "Codi_barri",
    "Nom barri": "Nom_barri",
    "Codi carrer": "Codi_carrer",
    "Nom carrer": "Nom_carrer",
    "Num postal caption": "Num_postal ",
    "Descripció dia setmana": "Descripcio_dia_setmana",
    'Dia setmana':"Dia_setmana",
    "NK Any":"NK_Any",
    "Mes de any": "Mes_any",
    "Nom mes": "Nom_mes",
    "Dia de mes": "Dia_mes",
    "Hora de dia": "Hora_dia",
    "Descripció torn": "Descripcio_torn",
    "Descripció tipus accident": "Descripcio_tipus_accident",
    "Coordenada UTM (Y)": "Coordenada_UTM_Y_ED50",
    "Coordenada UTM (X)": "Coordenada_UTM_X_ED50"
})

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on="Numero_expedient")

# %%
df
# Out:
#      Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0         2012S005688              10    Sant Martí  101-10-64
# 1         2012S005343              10    Sant Martí  101-10-64
# 2         2012S002291              10    Sant Martí  101-10-64
# 3         2012S005379              10    Sant Martí  101-10-64
# 4         2012S004837              10    Sant Martí  101-10-64
# ...               ...             ...           ...        ...
# 9814      2012S006787               9   Sant Andreu    93-9-59
# 9815      2012S004375               9   Sant Andreu    93-9-59
# 9816      2012S000898               9   Sant Andreu    93-9-59
# 9817      2012S002266               9   Sant Andreu    93-9-59
# 9818      2012S008119               9   Sant Andreu    93-9-59
#
#                        Nom_barri  Codi_carrer                Nom_carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# 1     el Camp de l'Arpa del Clot       226400       Las Navas de Tolosa
# 2     el Camp de l'Arpa del Clot       161407                 Indústria
# 3     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# ...                          ...          ...                       ...
# 9814               el Bon Pastor       295709                Sant Adrià
# 9815               el Bon Pastor       148908                Granadella
# 9816               el Bon Pastor       264308                    Potosí
# 9817               el Bon Pastor       347551                   Tucumán
# 9818               el Bon Pastor       701265           Litoral (Besòs)
#
#      Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 0      0203 0205               Dissabte               6  ...           Tarda
# 1      0337 0337               Diumenge               7  ...           Tarda
# 2      0288 0288                 Dijous               4  ...           Tarda
# 3      0356 0356                Dimarts               2  ...            Matí
# 4      0270 0270                Dimarts               2  ...           Tarda
# ...          ...                    ...             ...  ...             ...
# 9814   0109 0109              Divendres               5  ...            Matí
# 9815   0058 0058               Diumenge               7  ...             Nit
# 9816   0003 0003                Dimarts               2  ...            Matí
# 9817   0030 0030               Dimecres               3  ...           Tarda
# 9818   000120000                Dilluns               1  ...           Tarda
#
#              Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 0                          Desconegut             0                      1
# 1                          Desconegut             0                      1
# 2                          Desconegut             0                      1
# 3     Creuar per fora pas de vianants             0                      2
# 4                          Desconegut             0                      2
# ...                               ...           ...                    ...
# 9814                       Desconegut             0                      1
# 9815                       Desconegut             0                      0
# 9816                       Desconegut             0                      1
# 9817                       Desconegut             0                      2
# 9818                       Desconegut             0                      1
#
#       Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 0                          0                1                         2
# 1                          0                1                         2
# 2                          0                1                         2
# 3                          0                2                         1
# 4                          0                2                         1
# ...                      ...              ...                       ...
# 9814                       0                1                         2
# 9815                       0                0                         1
# 9816                       0                1                         2
# 9817                       0                2                         3
# 9818                       0                1                         2
#
#      Coordenada_UTM_Y_ED50  Coordenada_UTM_X_ED50   Descripcio_tipus_accident
# 0               4585178,54              432022,72    Col.lisió fronto-lateral
# 1               4585352,36              431860,84    Col.lisió fronto-lateral
# 2               4585102,28              431556,72           Col.lisió lateral
# 3               4585266,01              431552,73               Atropellament
# 4               4584898,92              431180,43  Xoc contra element estàtic
# ...                    ...                    ...                         ...
# 9814            4587491,96              433538,26                      Altres
# 9815            4587733,68              433790,15  Xoc contra element estàtic
# 9816            4588245,96              433206,25           Col.lisió lateral
# 9817            4588644,80              433417,16           Col.lisió lateral
# 9818            4588266,09              433713,00    Col.lisió fronto-lateral
#
# [9819 rows x 26 columns]

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#      Numero_expedient  Codi_districte        Nom_districte Codi_barri  \
# 3648      2012S000017               9          Sant Andreu    93-9-59
# 3647      2012S000017               9          Sant Andreu    93-9-59
# 3960      2012S000019               3       Sants-Montjuïc    32-3-12
# 3959      2012S000019               3       Sants-Montjuïc    32-3-12
# 3088      2012S000031              10           Sant Martí  102-10-73
# ...               ...             ...                  ...        ...
# 3822      2012S009255               2             Eixample     23-2-8
# 8981      2012S009256               4            Les Corts    43-4-21
# 8982      2012S009256               4            Les Corts    43-4-21
# 2257      2012S009257               5  Sarrià-Sant Gervasi    52-5-23
# 2256      2012S009257               5  Sarrià-Sant Gervasi    52-5-23
#
#                             Nom_barri  Codi_carrer     Nom_carrer Num_postal   \
# 3648                    el Bon Pastor       295709     Sant Adrià   0039 0039
# 3647                    el Bon Pastor       295709     Sant Adrià   0039 0039
# 3960       la Marina del Prat Vermell       369408    Zona Franca  0002C0002C
# 3959       la Marina del Prat Vermell       369408    Zona Franca  0002C0002C
# 3088              la Verneda i la Pau       153205      Guipúscoa   0103 0103
# ...                               ...          ...            ...         ...
# 3822  l'Antiga Esquerra de l'Eixample        23403         Aribau   0031 0031
# 8981                        Pedralbes       701267   Dalt (Besòs)   0011S0000
# 8982                        Pedralbes       701267   Dalt (Besòs)   0011S0000
# 2257                           Sarrià       193108  Manuel Girona   0043 0043
# 2256                           Sarrià       193108  Manuel Girona   0043 0043
#
#      Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 3648               Diumenge               7  ...             Nit
# 3647               Diumenge               7  ...             Nit
# 3960                Dilluns               1  ...             Nit
# 3959                Dilluns               1  ...             Nit
# 3088                Dilluns               1  ...           Tarda
# ...                     ...             ...  ...             ...
# 3822                Dilluns               1  ...            Matí
# 8981                Dilluns               1  ...            Matí
# 8982                Dilluns               1  ...            Matí
# 2257                Dilluns               1  ...            Matí
# 2256                Dilluns               1  ...            Matí
#
#       Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 3648                Desconegut             0                      1
# 3647                Desconegut             0                      1
# 3960                Desconegut             0                      0
# 3959                Desconegut             0                      0
# 3088                Desconegut             0                      0
# ...                        ...           ...                    ...
# 3822                Desconegut             0                      1
# 8981                Desconegut             0                      2
# 8982                Desconegut             0                      2
# 2257                Desconegut             0                      1
# 2256                Desconegut             0                      1
#
#       Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 3648                       0                1                         1
# 3647                       0                1                         1
# 3960                       0                0                         1
# 3959                       0                0                         1
# 3088                       0                0                         2
# ...                      ...              ...                       ...
# 3822                       0                1                         2
# 8981                       0                2                         3
# 8982                       0                2                         3
# 2257                       0                1                         3
# 2256                       0                1                         3
#
#      Coordenada_UTM_Y_ED50  Coordenada_UTM_X_ED50    Descripcio_tipus_accident
# 3648            4587371,93              432649,55   Xoc contra element estàtic
# 3647            4587371,93              432649,55  Bolcada (més de dues rodes)
# 3960            4577990,64              428593,33  Bolcada (més de dues rodes)
# 3959            4577990,64              428593,33   Xoc contra element estàtic
# 3088            4585694,34              433285,72            Col.lisió lateral
# ...                    ...                    ...                          ...
# 3822            4582070,61              429840,31            Col.lisió lateral
# 8981            4581732,74              424995,59                        Abast
# 8982            4581732,74              424995,59            Col.lisió lateral
# 2257            4582585,60              426868,80            Col.lisió lateral
# 2256            4582585,60              426868,80   Xoc contra element estàtic
#
# [1107 rows x 26 columns]

# %%
df = df.rename(columns={
    'Coordenada_UTM_X_ED50':"Coordenada_UTM_X",
       'Coordenada_UTM_Y_ED50':"Coordenada_UTM_Y",
         'Longitud_WGS84':"Longitud",
           'Latitud_WGS84':"Latitud"
})
df
# Out:
#      Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0         2012S005688              10    Sant Martí  101-10-64
# 1         2012S005343              10    Sant Martí  101-10-64
# 2         2012S002291              10    Sant Martí  101-10-64
# 3         2012S005379              10    Sant Martí  101-10-64
# 4         2012S004837              10    Sant Martí  101-10-64
# ...               ...             ...           ...        ...
# 9814      2012S006787               9   Sant Andreu    93-9-59
# 9815      2012S004375               9   Sant Andreu    93-9-59
# 9816      2012S000898               9   Sant Andreu    93-9-59
# 9817      2012S002266               9   Sant Andreu    93-9-59
# 9818      2012S008119               9   Sant Andreu    93-9-59
#
#                        Nom_barri  Codi_carrer                Nom_carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# 1     el Camp de l'Arpa del Clot       226400       Las Navas de Tolosa
# 2     el Camp de l'Arpa del Clot       161407                 Indústria
# 3     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# ...                          ...          ...                       ...
# 9814               el Bon Pastor       295709                Sant Adrià
# 9815               el Bon Pastor       148908                Granadella
# 9816               el Bon Pastor       264308                    Potosí
# 9817               el Bon Pastor       347551                   Tucumán
# 9818               el Bon Pastor       701265           Litoral (Besòs)
#
#      Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Descripcio_torn  \
# 0      0203 0205               Dissabte               6  ...           Tarda
# 1      0337 0337               Diumenge               7  ...           Tarda
# 2      0288 0288                 Dijous               4  ...           Tarda
# 3      0356 0356                Dimarts               2  ...            Matí
# 4      0270 0270                Dimarts               2  ...           Tarda
# ...          ...                    ...             ...  ...             ...
# 9814   0109 0109              Divendres               5  ...            Matí
# 9815   0058 0058               Diumenge               7  ...             Nit
# 9816   0003 0003                Dimarts               2  ...            Matí
# 9817   0030 0030               Dimecres               3  ...           Tarda
# 9818   000120000                Dilluns               1  ...           Tarda
#
#              Descripcio_causa_vianant  Numero_morts Numero_lesionats_lleus  \
# 0                          Desconegut             0                      1
# 1                          Desconegut             0                      1
# 2                          Desconegut             0                      1
# 3     Creuar per fora pas de vianants             0                      2
# 4                          Desconegut             0                      2
# ...                               ...           ...                    ...
# 9814                       Desconegut             0                      1
# 9815                       Desconegut             0                      0
# 9816                       Desconegut             0                      1
# 9817                       Desconegut             0                      2
# 9818                       Desconegut             0                      1
#
#       Numero_lesionats_greus  Numero_victimes Numero_vehicles_implicats  \
# 0                          0                1                         2
# 1                          0                1                         2
# 2                          0                1                         2
# 3                          0                2                         1
# 4                          0                2                         1
# ...                      ...              ...                       ...
# 9814                       0                1                         2
# 9815                       0                0                         1
# 9816                       0                1                         2
# 9817                       0                2                         3
# 9818                       0                1                         2
#
#      Coordenada_UTM_Y  Coordenada_UTM_X   Descripcio_tipus_accident
# 0          4585178,54         432022,72    Col.lisió fronto-lateral
# 1          4585352,36         431860,84    Col.lisió fronto-lateral
# 2          4585102,28         431556,72           Col.lisió lateral
# 3          4585266,01         431552,73               Atropellament
# 4          4584898,92         431180,43  Xoc contra element estàtic
# ...               ...               ...                         ...
# 9814       4587491,96         433538,26                      Altres
# 9815       4587733,68         433790,15  Xoc contra element estàtic
# 9816       4588245,96         433206,25           Col.lisió lateral
# 9817       4588644,80         433417,16           Col.lisió lateral
# 9818       4588266,09         433713,00    Col.lisió fronto-lateral
#
# [9819 rows x 26 columns]

# %%
df["Longitud"] = None
df["Latitud"]= None

# %%
df["Codi_barri"] = df["Codi_barri"].astype(str).str.extract(r'-?(\d+)$')
df
# Out:
#      Numero_expedient  Codi_districte Nom_districte Codi_barri  \
# 0         2012S005688              10    Sant Martí         64
# 1         2012S005343              10    Sant Martí         64
# 2         2012S002291              10    Sant Martí         64
# 3         2012S005379              10    Sant Martí         64
# 4         2012S004837              10    Sant Martí         64
# ...               ...             ...           ...        ...
# 9814      2012S006787               9   Sant Andreu         59
# 9815      2012S004375               9   Sant Andreu         59
# 9816      2012S000898               9   Sant Andreu         59
# 9817      2012S002266               9   Sant Andreu         59
# 9818      2012S008119               9   Sant Andreu         59
#
#                        Nom_barri  Codi_carrer                Nom_carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# 1     el Camp de l'Arpa del Clot       226400       Las Navas de Tolosa
# 2     el Camp de l'Arpa del Clot       161407                 Indústria
# 3     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 4     el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# ...                          ...          ...                       ...
# 9814               el Bon Pastor       295709                Sant Adrià
# 9815               el Bon Pastor       148908                Granadella
# 9816               el Bon Pastor       264308                    Potosí
# 9817               el Bon Pastor       347551                   Tucumán
# 9818               el Bon Pastor       701265           Litoral (Besòs)
#
#      Num_postal  Descripcio_dia_setmana  Dia de setmana  ... Numero_morts  \
# 0      0203 0205               Dissabte               6  ...            0
# 1      0337 0337               Diumenge               7  ...            0
# 2      0288 0288                 Dijous               4  ...            0
# 3      0356 0356                Dimarts               2  ...            0
# 4      0270 0270                Dimarts               2  ...            0
# ...          ...                    ...             ...  ...          ...
# 9814   0109 0109              Divendres               5  ...            0
# 9815   0058 0058               Diumenge               7  ...            0
# 9816   0003 0003                Dimarts               2  ...            0
# 9817   0030 0030               Dimecres               3  ...            0
# 9818   000120000                Dilluns               1  ...            0
#
#       Numero_lesionats_lleus  Numero_lesionats_greus Numero_victimes  \
# 0                          1                       0               1
# 1                          1                       0               1
# 2                          1                       0               1
# 3                          2                       0               2
# 4                          2                       0               2
# ...                      ...                     ...             ...
# 9814                       1                       0               1
# 9815                       0                       0               0
# 9816                       1                       0               1
# 9817                       2                       0               2
# 9818                       1                       0               1
#
#       Numero_vehicles_implicats  Coordenada_UTM_Y Coordenada_UTM_X  \
# 0                             2        4585178,54        432022,72
# 1                             2        4585352,36        431860,84
# 2                             2        4585102,28        431556,72
# 3                             1        4585266,01        431552,73
# 4                             1        4584898,92        431180,43
# ...                         ...               ...              ...
# 9814                          2        4587491,96        433538,26
# 9815                          1        4587733,68        433790,15
# 9816                          2        4588245,96        433206,25
# 9817                          3        4588644,80        433417,16
# 9818                          2        4588266,09        433713,00
#
#        Descripcio_tipus_accident  Longitud  Latitud
# 0       Col.lisió fronto-lateral      None     None
# 1       Col.lisió fronto-lateral      None     None
# 2              Col.lisió lateral      None     None
# 3                  Atropellament      None     None
# 4     Xoc contra element estàtic      None     None
# ...                          ...       ...      ...
# 9814                      Altres      None     None
# 9815  Xoc contra element estàtic      None     None
# 9816           Col.lisió lateral      None     None
# 9817           Col.lisió lateral      None     None
# 9818    Col.lisió fronto-lateral      None     None
#
# [9819 rows x 28 columns]

# %%
df.to_csv("../data/df_2012.csv", index = False)

# %%
#df.groupby("Numero_expedient").sum("")
