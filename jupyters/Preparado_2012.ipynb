# %% [markdown]
# # Preparación 2014

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("../data/2012_ACCIDENTS_GU_BCN_2012.csv", encoding="Windows 1252")
df2 = pd.read_csv("../data/2012_ACCIDENTS_TIPUS_GU_BCN_2012.csv", encoding="cp850")

# %%
df1
# Out:
#      Número d'expedient  Codi districte Nom districte   NK barri  \
# 0           2012S005688              10    Sant Martí  101-10-64
# 1           2012S005343              10    Sant Martí  101-10-64
# 2           2012S002291              10    Sant Martí  101-10-64
# 3           2012S005379              10    Sant Martí  101-10-64
# 4           2012S004837              10    Sant Martí  101-10-64
# ...                 ...             ...           ...        ...
# 9248        2012S006787               9   Sant Andreu    93-9-59
# 9249        2012S004375               9   Sant Andreu    93-9-59
# 9250        2012S000898               9   Sant Andreu    93-9-59
# 9251        2012S002266               9   Sant Andreu    93-9-59
# 9252        2012S008119               9   Sant Andreu    93-9-59
#
#                        Nom barri  Codi carrer                Nom carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# ...

# %%
df1
# Out:
#      Número d'expedient  Codi districte Nom districte   NK barri  \
# 0           2012S005688              10    Sant Martí  101-10-64
# 1           2012S005343              10    Sant Martí  101-10-64
# 2           2012S002291              10    Sant Martí  101-10-64
# 3           2012S005379              10    Sant Martí  101-10-64
# 4           2012S004837              10    Sant Martí  101-10-64
# ...                 ...             ...           ...        ...
# 9248        2012S006787               9   Sant Andreu    93-9-59
# 9249        2012S004375               9   Sant Andreu    93-9-59
# 9250        2012S000898               9   Sant Andreu    93-9-59
# 9251        2012S002266               9   Sant Andreu    93-9-59
# 9252        2012S008119               9   Sant Andreu    93-9-59
#
#                        Nom barri  Codi carrer                Nom carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# ...

# %%
col1_corr = df1.columns.str.replace(" ","_")
col1_corr = col1_corr.str.replace("_de","")
col1_corr=col1_corr.str.replace("d'","")
col1_corr=col1_corr.str.replace("ú","u")
col1_corr
# Out:
# Index(['Numero_expedient', 'Codi_districte', 'Nom_districte', 'NK_barri',
#        'Nom_barri', 'Codi_carrer', 'Nom_carrer', 'Num_postal_caption',
#        'Descripció_dia_setmana', 'Dia_setmana', 'Descripció_tipus_dia',
#        'NK_Any', 'Mes_any', 'Nom_mes', 'Dia_mes', 'Hora_dia',
#        'Descripció_torn', 'Descripció_causa_vianant', 'Numero_morts',
#        'Numero_lesionats_lleus', 'Numero_lesionats_greus', 'Numero_víctimes',
#        'Numero_vehicles_implicats', 'Coordenada_UTM_(Y)',
#        'Coordenada_UTM_(X)'],
#       dtype='object')

# %%
dict = {}
for i,val in enumerate(df1.columns):
    dict[val] = col1_corr[i]

dict
# Out:
# {"Número d'expedient": 'Numero_expedient',
#  'Codi districte': 'Codi_districte',
#  'Nom districte': 'Nom_districte',
#  'NK barri': 'NK_barri',
#  'Nom barri': 'Nom_barri',
#  'Codi carrer': 'Codi_carrer',
#  'Nom carrer': 'Nom_carrer',
#  'Num postal caption': 'Num_postal_caption',
#  'Descripció dia setmana': 'Descripció_dia_setmana',
#  'Dia de setmana': 'Dia_setmana',
#  'Descripció tipus dia': 'Descripció_tipus_dia',
#  'NK Any': 'NK_Any',
#  'Mes de any': 'Mes_any',
#  'Nom mes': 'Nom_mes',
#  'Dia de mes': 'Dia_mes',
#  'Hora de dia': 'Hora_dia',
#  'Descripció torn': 'Descripció_torn',
#  'Descripció causa vianant': 'Descripció_causa_vianant',
#  'Número de morts': 'Numero_morts',
#  'Número de lesionats lleus': 'Numero_lesionats_lleus',
#  'Número de lesionats greus': 'Numero_lesionats_greus',
#  'Número de víctimes': 'Numero_víctimes',
#  'Número de vehicles implicats': 'Numero_vehicles_implicats',
#  'Coordenada UTM (Y)': 'Coordenada_UTM_(Y)',
# ...

# %%
df1.rename(columns=dict,inplace=True)
df1
# Out:
#      Numero_expedient  Codi_districte Nom_districte   NK_barri  \
# 0         2012S005688              10    Sant Martí  101-10-64
# 1         2012S005343              10    Sant Martí  101-10-64
# 2         2012S002291              10    Sant Martí  101-10-64
# 3         2012S005379              10    Sant Martí  101-10-64
# 4         2012S004837              10    Sant Martí  101-10-64
# ...               ...             ...           ...        ...
# 9248      2012S006787               9   Sant Andreu    93-9-59
# 9249      2012S004375               9   Sant Andreu    93-9-59
# 9250      2012S000898               9   Sant Andreu    93-9-59
# 9251      2012S002266               9   Sant Andreu    93-9-59
# 9252      2012S008119               9   Sant Andreu    93-9-59
#
#                        Nom_barri  Codi_carrer                Nom_carrer  \
# 0     el Camp de l'Arpa del Clot       209900                 Meridiana
# ...

# %%
df1.rename(columns={"Número d expedient":"Numero_expedient"}, inplace=True)

# %%
df2
# Out:
#      Número d'expedient Codi districte Nom districte Codi barri  \
# 0           2012S005688             10    Sant Martí         64
# 1           2012S002763             10    Sant Martí         64
# 2           2012S007349             10    Sant Martí         64
# 3           2012S003847             10    Sant Martí         64
# 4           2012S009254             10    Sant Martí         64
# ...                 ...            ...           ...        ...
# 9814        2012S005002              9   Sant Andreu         59
# 9815        2012S008561              9   Sant Andreu         59
# 9816        2012S005771              9   Sant Andreu         59
# 9817        2012S008931              9   Sant Andreu         59
# 9818        2012S007067              9   Sant Andreu         59
#
#                        Nom barri Codi carrer       Nom carrer  \
# 0     el Camp de l'Arpa del Clot      209900        Meridiana
# 1     el Camp de l'Arpa del Clot      194406         Maragall
# ...

# %%
df1.rename(columns={"Número d'expedient":"Numero_expedient"}, inplace=True)

# %%
df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on="Numero_expedient")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = df1.merge(df2[["Numero_expedient","Descripcio_tipus_accident"]], how = "inner", on="Numero_expedient")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
df[df["Numero_expedient"].isin( df[df["Numero_expedient"].duplicated()]["Numero_expedient"])].sort_values("Numero_expedient")
# Out:
#       Numero_expedient  Codi_districte        Nom_districte  Codi_barri  \
# 1646   2016S000004                   2             Eixample           8
# 1647   2016S000004                   2             Eixample           8
# 10388  2016S000024                   5  Sarrià-Sant Gervasi          27
# 10387  2016S000024                   5  Sarrià-Sant Gervasi          27
# 515    2016S000039                   2             Eixample           7
# ...                ...             ...                  ...         ...
# 5136   2016S010014                   7       Horta-Guinardó          40
# 5395   2016S010036                  10           Sant Martí          73
# 5396   2016S010036                  10           Sant Martí          73
# 8883   2016S010127                   4            Les Corts          19
# 8884   2016S010127                   4            Les Corts          19
#
#                              Nom_barri  Codi_carrer           Nom_carrer  \
# ...

# %%
df.rename(columns={"Tipus_accident":"Descripcio_tipus_accident"},inplace=True)

# %%
dum = pd.get_dummies(df["Descripcio_tipus_accident"]).astype("uint8")

# %%
df = pd.concat([df.drop(columns="Descripcio_tipus_accident"),dum],axis = 1)
df
# Out:
#       Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0      2018S000150                   3  Sants-Montjuïc          12
# 1      2018S000150                   3  Sants-Montjuïc          12
# 2      2018S000761                   3  Sants-Montjuïc          11
# 3      2018S000761                   3  Sants-Montjuïc          11
# 4      2018S005151                   3  Sants-Montjuïc          12
# ...                ...             ...             ...         ...
# 10557  2018S003036                   8      Nou Barris          55
# 10558  2018S003108                   8      Nou Barris          55
# 10559  2018S009777                   8      Nou Barris          55
# 10560  2018S000005                   8      Nou Barris          56
# 10561  2018S004375                   8      Nou Barris          56
#
#                         Nom_barri  Codi_carrer  \
# 0      la Marina del Prat Vermell       701819
# 1      la Marina del Prat Vermell       701819
# ...

# %%
#df.groupby("Numero_expedient").sum("")
